# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in e:\utsav\biz projects\theastropulse\backend\venv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in e:\utsav\biz projects\theastropulse\backend\venv\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import cv2
import io
from datetime import datetime
import mediapipe as mp
from skimage.filters import meijering
from skimage.morphology import skeletonize
from skimage.util import img_as_ubyte

# %%
def process_image(image_path):
    img = cv2.imread(image_path)
    if img is None:
        print("Image not loaded. Check path or format.")
        return

        # ------------------ 1. Background Removal ------------------
    mp_selfie_segmentation = mp.solutions.selfie_segmentation
    with mp_selfie_segmentation.SelfieSegmentation(model_selection=1) as segmentor:
        rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        result = segmentor.process(rgb_img)
        mask = result.segmentation_mask
        mask = cv2.GaussianBlur(mask, (15, 15), 0)
        mask_3ch = np.stack([mask] * 3, axis=-1)
        mask_3ch = (mask_3ch > 0.2).astype(np.uint8)
        white_bg = np.ones_like(img, dtype=np.uint8) * 255
        img = (img * mask_3ch + white_bg * (1 - mask_3ch)).astype(np.uint8)

    # ------------------ 2. Enhancement Filters ------------------
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    clahe = cv2.createCLAHE(clipLimit=3, tileGridSize=(5, 5))
    enhanced = clahe.apply(gray)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (30, 30))
    tophat = cv2.morphologyEx(enhanced, cv2.MORPH_TOPHAT, kernel)
    combined = cv2.addWeighted(enhanced, 0.1, tophat, 0.1, 0)
    

    meij = meijering(combined / 255.0, sigmas=range(1, 6), black_ridges=True)
    meij = img_as_ubyte(meij)

    _, binary = cv2.threshold(meij, 27, 255, cv2.THRESH_BINARY)
    skeleton = skeletonize(binary // 255)
    skeleton = (skeleton * 255).astype(np.uint8)

    # ------------------ 3. Morphological Closing ------------------
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    closed = cv2.morphologyEx(skeleton, cv2.MORPH_CLOSE, kernel, iterations=0)

    # ------------------ 4. Line Detection ------------------
    edges = cv2.Canny(closed, 30, 120)
    lines = cv2.HoughLinesP(edges, 1, np.pi / 180, threshold=100, minLineLength=150, maxLineGap=20)
    contours, _ = cv2.findContours(closed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    
    height, width = gray.shape
    line_img = cv2.cvtColor(closed, cv2.COLOR_GRAY2BGR)

    # ------------------ 5. Draw Outer Hand Border ------------------
    if contours:
        largest = max(contours, key=cv2.contourArea)
        if cv2.contourArea(largest) > 1000:
            cv2.drawContours(line_img, [largest], -1, (255, 255, 255), 1)  # White border

    cv2.imshow("Palm Lines", line_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()


process_image("./image.png")

# %% [markdown]
# below is better version

# %%
import cv2
import numpy as np
import mediapipe as mp
from skimage.morphology import skeletonize
from skimage.filters import meijering
from skimage.util import img_as_ubyte
import matplotlib.pyplot as plt

def process_image3(image_path):
    """
    Processes a hand image to extract and identify the Heart, Head, and Life lines.

    Args:
        image_path (str): The path to the input hand image.
    """
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Image not loaded from {image_path}. Check path or format.")
        return

    print(f"Processing image: {image_path}")

    # --- 1. Robust Background Removal using MediaPipe ---
    # This helps in isolating the hand regardless of skin tone or complex backgrounds.
    mp_selfie_segmentation = mp.solutions.selfie_segmentation
    with mp_selfie_segmentation.SelfieSegmentation(model_selection=1) as segmentor:
        rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        result = segmentor.process(rgb_img)
        mask = result.segmentation_mask

        # Apply a Gaussian blur to the mask to smooth edges
        mask = cv2.GaussianBlur(mask, (15, 15), 0)

        # Create a 3-channel mask for element-wise multiplication
        mask_3ch = np.stack([mask] * 3, axis=-1)

        # Threshold the mask to create a binary mask of the hand (foreground)
        # Using a slightly lower threshold (0.1) can capture more faint hand edges
        hand_mask_binary = (mask_3ch > 0.1).astype(np.uint8)

        # Create a white background
        white_bg = np.ones_like(img, dtype=np.uint8) * 255

        # Apply the mask: hand remains, background becomes white
        img_no_bg = (img * hand_mask_binary + white_bg * (1 - hand_mask_binary)).astype(np.uint8)

    # --- 2. Line Enhancement Filters ---
    # Convert to grayscale for line detection
    gray = cv2.cvtColor(img_no_bg, cv2.COLOR_BGR2GRAY)

    # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization) for better contrast
    # This helps enhance faint lines across different lighting conditions
    clahe = cv2.createCLAHE(clipLimit=3, tileGridSize=(7, 7)) # Increased tile size slightly
    enhanced = clahe.apply(gray)

    # Apply Top-Hat transform to highlight bright features (lines) on a dark background
    # This helps in isolating lines from general skin texture
    kernel_tophat = cv2.getStructuringElement(cv2.MORPH_RECT, (30, 30))
    tophat = cv2.morphologyEx(enhanced, cv2.MORPH_TOPHAT, kernel_tophat)
    
    # Combine enhanced image with tophat result for overall line prominence
    combined = cv2.addWeighted(enhanced, 0.5, tophat, 0.5, 0) # Increased weights for both

    # Meijering filter: specializes in detecting vessel-like (line-like) structures
    meij = meijering(combined / 255.0, sigmas=range(1, 8), black_ridges=True) # Increased max sigma
    meij = img_as_ubyte(meij) # Convert back to uint8 (0-255)

    # Adaptive Thresholding: Use OTSU's method to automatically find the best threshold
    # for converting the Meijering result into a binary image of lines.
    # This is more robust than a fixed threshold (like 27) for varying lighting/contrast.
    _, binary = cv2.threshold(meij, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    # Display binary for debugging
    # cv2.imshow("Debug: Binary Image before Skeletonization (OTSU)", binary)

    # Skeletonization: Reduces lines to 1-pixel width, simplifying contour analysis
    skeleton = skeletonize(binary // 255) # Convert to boolean (0 or 1) for skeletonize
    skeleton = (skeleton * 255).astype(np.uint8) # Convert back to 0-255

    # --- 3. Morphological Closing ---
    # Fills small gaps in lines, ensuring better connectivity for contours
    kernel_close = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    closed = cv2.morphologyEx(skeleton, cv2.MORPH_CLOSE, kernel_close, iterations=1) # Apply once

    # Display closed image for debugging connection
    # cv2.imshow("Debug: Closed Image (Lines Connected)", closed)


    # --- 4. Line Detection (Contours) ---
    # Find contours (lines) on the processed binary image
    contours, _ = cv2.findContours(closed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    height, width = gray.shape # Get dimensions of the hand image

    # --- 5. Filter Longest and Smallest Lines ---
    # Removes noise (very short lines) and large artifacts (like hand border if not fully removed)
    filtered_contours = []
    if contours:
        contour_lengths = [cv2.arcLength(c, False) for c in contours]

        # Dynamic length thresholds based on image dimensions
        min_length_ratio = 0.02  # Minimum length as % of the smaller image dimension
        max_length_ratio = 0.85  # Maximum length as % of the larger image dimension (allow long lines)

        min_length_threshold = min(height, width) * min_length_ratio
        max_length_threshold = max(height, width) * max_length_ratio

        print(f"\nInitial contours found: {len(contours)}")
        print(f"Length thresholds: Min={min_length_threshold:.2f}, Max={max_length_threshold:.2f}")

        for contour, length in zip(contours, contour_lengths):
            if length > min_length_threshold and length < max_length_threshold:
                filtered_contours.append(contour)

        print(f"Contours after length filtering: {len(filtered_contours)}")

        # Optional refinement: remove a few absolute shortest/longest from the remaining
        # This helps in case initial thresholds are not perfect.
        if len(filtered_contours) > 5: # Only if we have enough lines left
            filtered_contours.sort(key=lambda c: cv2.arcLength(c, False))
            # Remove a small number of the shortest lines (e.g., 1-2)
            num_to_remove_shortest = min(2, len(filtered_contours) // 8)
            filtered_contours = filtered_contours[num_to_remove_shortest:]

            # Removed explicit longest removal here; relying on max_length_ratio and classification.
            # If a major border artifact persists, you might need to reintroduce this carefully.

    # --- Initialize Variables for the Three Main Lines ---
    heart_line = None
    head_line = None
    life_line = None

    # --- 6. Feature Extraction for Classification ---
    # Extract properties (position, length, angle, straightness) for each filtered contour
    line_candidates_info = []
    for i, contour in enumerate(filtered_contours):
        x, y, w, h = cv2.boundingRect(contour) # Bounding box
        
        M = cv2.moments(contour) # Moments for centroid
        cx, cy = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"])) if M["m00"] != 0 else (x + w // 2, y + h // 2)

        length = cv2.arcLength(contour, False) # Contour length

        angle = 0
        straightness = 0
        if len(contour) >= 5: # `minAreaRect` needs at least 5 points
            rect = cv2.minAreaRect(contour)
            center, dims, raw_angle = rect
            
            # Normalize angle to be 0-90 degrees (0 = horizontal, 90 = vertical)
            if dims[0] < dims[1]: # If width is less than height, it's more vertical
                angle = 90 + raw_angle # Adjust for vertical lines
            else: # If width is greater than height, it's more horizontal
                angle = abs(raw_angle) # Keep abs for horizontal lines
            
            # Straightness: ratio of shorter to longer side of the min-area rectangle
            straightness = min(dims) / max(dims) if max(dims) > 0 else 0
        
        # Add relative position (normalized to hand size)
        relative_cy = cy / height
        relative_cx = cx / width

        line_candidates_info.append({
            'id': i, # Original index for tracking
            'contour': contour,
            'bbox': (x, y, w, h),
            'cx': cx, 'cy': cy,
            'relative_cx': relative_cx,
            'relative_cy': relative_cy,
            'length': length,
            'angle': angle, # Angle in degrees (0 = horizontal, 90 = vertical)
            'straightness': straightness, # 1 for very straight, <1 for curved
        })
    
    print(f"\nCandidates for main line classification: {len(line_candidates_info)}")
    # Print properties for each candidate for detailed debugging
    for i, lc in enumerate(line_candidates_info):
        print(f"Cand {lc['id']}: Len={lc['length']:.1f}, Angle={lc['angle']:.1f}, Straight={lc['straightness']:.2f}, "
              f"RCY={lc['relative_cy']:.2f}, RCX={lc['relative_cx']:.2f}, BBox=({lc['bbox'][0]},{lc['bbox'][1]},{lc['bbox'][2]},{lc['bbox'][3]})")

    classified_contours_ids = set() # To prevent re-classifying the same contour

    # --- 7. Heuristic-Based Line Classification ---
    # This section applies rules based on typical palm line characteristics.
    # Order of classification matters (Heart -> Head -> Life)

    # --- 7.1. Identify Heart Line ---
    # Characteristics: Highest prominent horizontal line
    heart_candidates = []
    for i, lc in enumerate(line_candidates_info):
        # Y position: Generally in the upper 40-55% of the hand
        # Length: Must be substantial (e.g., at least 30% of image width)
        # Angle: Predominantly horizontal (angle close to 0)
        if lc['relative_cy'] < 0.55 and \
           lc['length'] > width * 0.25 and \
           lc['angle'] < 40: # Increased angle tolerance for slight curves
            heart_candidates.append(lc)
    
    if heart_candidates:
        heart_candidates.sort(key=lambda x: x['relative_cy']) # Pick the highest (smallest relative_cy)
        heart_line = heart_candidates[0]['contour']
        heart_line_data = heart_candidates[0] # Store full data for future reference
        classified_contours_ids.add(heart_line_data['id'])
        print(f"Heart line candidate found (ID: {heart_line_data['id']}). Relative CY: {heart_line_data['relative_cy']:.2f}")

    # --- 7.2. Identify Head Line ---
    # Characteristics: Below heart line, also relatively horizontal/slanted, often longest of horizontals.
    head_candidates = []
    for i, lc in enumerate(line_candidates_info):
        if lc['id'] not in classified_contours_ids:
            # Y position: Below heart line, in the middle 30-75% of the hand
            # Length: Substantial, often comparable to heart line
            # Angle: Can be more slanted than heart line
            if lc['relative_cy'] > 0.30 and lc['relative_cy'] < 0.75 and \
               lc['length'] > width * 0.25 and lc['angle'] < 55: # More angle tolerance
                # Ensure it's below the heart line if heart line was found
                if heart_line is None or lc['relative_cy'] > heart_line_data['relative_cy'] + 0.05: # At least 5% lower
                    head_candidates.append(lc)
    
    if head_candidates:
        # Prioritize by Y position, then length (longer preferred)
        head_candidates.sort(key=lambda x: (x['relative_cy'], -x['length']))
        head_line = head_candidates[0]['contour']
        head_line_data = head_candidates[0]
        classified_contours_ids.add(head_line_data['id'])
        print(f"Head line candidate found (ID: {head_line_data['id']}). Relative CY: {head_line_data['relative_cy']:.2f}")

    # --- 7.3. Identify Life Line ---
    # Characteristics: Longest, most curved, typically starts near thumb base, sweeps downwards.
    life_candidates = []
    for i, lc in enumerate(line_candidates_info):
        if lc['id'] not in classified_contours_ids:
            # Origin point (for a left hand, assumed standard orientation): Top-left region
            # This is the most sensitive heuristic. Adjust these '0.40' values for your images.
            is_origin_in_thumb_base_area = (lc['relative_cx'] < 0.40 and lc['relative_cy'] < 0.40)
            
            # Shape characteristics: Long, significant vertical and horizontal spread, curved.
            # Its straightness will be lower than heart/head lines, and its angle will be more vertical.
            is_long_and_curved = (lc['length'] > width * 0.35 and # Must be quite long
                                  lc['bbox'][3] > height * 0.35 and # Significant vertical span
                                  lc['bbox'][2] > width * 0.20 and # Significant horizontal span
                                  lc['straightness'] < 0.6 and # Not very straight
                                  lc['angle'] > 30 and lc['angle'] < 80) # More vertical/diagonal angle
            
            # Combine conditions to prioritize the best fit
            if is_origin_in_thumb_base_area and is_long_and_curved:
                 life_candidates.append(lc)
            # Fallback: Longest remaining candidate that shows good vertical extent and is somewhat curved
            elif lc['length'] > width * 0.40 and lc['bbox'][3] > height * 0.40 and lc['straightness'] < 0.7:
                 life_candidates.append(lc)

    if life_candidates:
        # Prioritize by combination of length and straightness (more curved, longer preferred)
        life_candidates.sort(key=lambda x: (x['straightness'], -x['length']))
        life_line = life_candidates[0]['contour']
        life_line_data = life_candidates[0]
        classified_contours_ids.add(life_line_data['id'])
        print(f"Life line candidate found (ID: {life_line_data['id']}). Length: {life_line_data['length']:.1f}")
    
    # --- Final Classification Summary ---
    print("\n--- Final Classification Results ---")
    if heart_line is None: print("Heart Line: NOT FOUND")
    if head_line is None: print("Head Line: NOT FOUND")
    if life_line is None: print("Life Line: NOT FOUND")
    
    # Debugging: Print info about unclassified lines (very helpful for tuning)
    if len(classified_contours_ids) < 3:
        print("\n--- Remaining unclassified lines (potential missed main lines or noise): ---")
        for lc in line_candidates_info:
            if lc['id'] not in classified_contours_ids:
                print(f"Unclassified Cand {lc['id']}: Len={lc['length']:.1f}, Angle={lc['angle']:.1f}, Straight={lc['straightness']:.2f}, "
                      f"RCY={lc['relative_cy']:.2f}, RCX={lc['relative_cx']:.2f}, BBox=({lc['bbox'][0]},{lc['bbox'][1]},{lc['bbox'][2]},{lc['bbox'][3]})")


    # --- 8. Draw the Identified Lines on the Original Image ---
    # Create a blank grayscale canvas of the same size as input image
    three_lines_img_gray = np.zeros((height, width), dtype=np.uint8)
    # Convert it to 3-channel BGR for drawing colored lines
    three_lines_img = cv2.cvtColor(three_lines_img_gray, cv2.COLOR_GRAY2BGR)

    # Make a copy of the background-removed image to overlay lines
    output_on_original = img_no_bg.copy()

    # Draw identified lines in distinct colors
    if heart_line is not None:
        cv2.drawContours(three_lines_img, [heart_line], -1, (0, 0, 255), 2) # Red
        cv2.drawContours(output_on_original, [heart_line], -1, (0, 0, 255), 2)
    if head_line is not None:
        cv2.drawContours(three_lines_img, [head_line], -1, (0, 255, 255), 2) # Yellow
        cv2.drawContours(output_on_original, [head_line], -1, (0, 255, 255), 2)
    if life_line is not None:
        cv2.drawContours(three_lines_img, [life_line], -1, (0, 255, 0), 2) # Green
        cv2.drawContours(output_on_original, [life_line], -1, (0, 255, 0), 2)

    # Display results
    cv2.imshow("Extracted Main Palm Lines (Isolated)", three_lines_img)
    cv2.imshow("Main Lines Overlayed on Hand", output_on_original)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# --- Example Usage ---
# Make sure 'simple_image.png' (or your actual image file) is in the same directory as this script.
process_image3("./image.png")
# Out:
# Processing image: ./image.png
#
# Initial contours found: 598
# Length thresholds: Min=19.20, Max=1088.00
# Contours after length filtering: 94
#
# Candidates for main line classification: 92
# Cand 0: Len=20.9, Angle=161.6, Straight=0.52, RCY=0.46, RCX=0.35, BBox=(332,585,7,6)
# Cand 1: Len=21.3, Angle=116.6, Straight=0.16, RCY=0.72, RCX=0.15, BBox=(142,912,6,11)
# Cand 2: Len=21.6, Angle=35.0, Straight=0.07, RCY=0.59, RCX=0.47, BBox=(450,750,11,8)
# Cand 3: Len=22.1, Angle=29.7, Straight=0.06, RCY=0.64, RCX=0.37, BBox=(350,819,11,7)
# Cand 4: Len=22.4, Angle=39.8, Straight=0.06, RCY=0.58, RCX=0.46, BBox=(435,739,10,8)
# Cand 5: Len=22.7, Angle=77.5, Straight=0.08, RCY=0.59, RCX=0.54, BBox=(514,754,3,14)
# Cand 6: Len=22.8, Angle=85.6, Straight=0.05, RCY=0.35, RCX=0.75, BBox=(719,434,2,18)
# Cand 7: Len=23.0, Angle=0.0, Straight=0.00, RCY=0.92, RCX=0.97, BBox=(930,1162,1,24)
# Cand 8: Len=23.1, Angle=15.3, Straight=0.31, RCY=0.41, RCX=0.68, BBox=(643,527,12,6)
# Cand 9: Len=23.8, Angle=84.3, Straight=0.06, RCY=0.52, RCX=0.63, BBox=(600,654,2,17)
# Cand 10: Len=24.0, Angle=59.0, Straight=0.07, RCY=0.71, RCX=0.55, BBox=(523,904,7,11)
# Cand 11: Len=24.1, Angle=130.6, Straight=0.15, RCY=0.82, RCX=0.29, BBox=(270,1043,9,10)
# Cand 12: Len=24.7, Angle=14.0, Straight=0.22, RCY=0.09, RCX=0.64, BBox=(604,111,13,6)
# Cand 13: Len=25.2, Angle=40.6, Straight=0.05, RCY=0.76, RCX=0.35, BBox=(335,968,11,9)
# Cand 14: Len=26.4, Angle=84.3, Straight=0.52, RCY=0.50, RCX=0.44, BBox=(424,633,7,11)
# Cand 15: Len=26.6, Angle=48.0, Straight=0.10, RCY=0.73, RCX=0.43, BBox=(407,928,10,11)
# Cand 16: Len=27.1, Angle=9.5, Straight=0.11, RCY=0.59, RCX=0.32, BBox=(300,753,14,4)
# Cand 17: Len=27.7, Angle=8.1, Straight=0.06, RCY=0.59, RCX=0.66, BBox=(629,749,16,3)
# Cand 18: Len=29.3, Angle=116.6, Straight=0.20, RCY=0.41, RCX=0.65, BBox=(625,522,7,13)
# Cand 19: Len=29.5, Angle=169.7, Straight=0.09, RCY=0.23, RCX=0.57, BBox=(540,288,19,4)
# Cand 20: Len=29.7, Angle=94.8, Straight=0.06, RCY=0.82, RCX=0.77, BBox=(736,1039,3,16)
# Cand 21: Len=30.1, Angle=20.6, Straight=0.08, RCY=0.59, RCX=0.64, BBox=(607,754,15,6)
# Cand 22: Len=30.5, Angle=77.5, Straight=0.09, RCY=0.61, RCX=0.54, BBox=(517,771,4,16)
# Cand 23: Len=30.7, Angle=174.3, Straight=0.06, RCY=0.28, RCX=0.47, BBox=(444,355,22,3)
# Cand 24: Len=31.6, Angle=68.2, Straight=0.59, RCY=0.99, RCX=0.24, BBox=(233,1264,9,11)
# Cand 25: Len=32.0, Angle=9.5, Straight=0.35, RCY=0.49, RCX=0.46, BBox=(434,621,13,6)
# Cand 26: Len=33.2, Angle=61.7, Straight=0.08, RCY=0.63, RCX=0.47, BBox=(450,796,9,15)
# Cand 27: Len=33.8, Angle=4.1, Straight=0.05, RCY=0.34, RCX=0.61, BBox=(574,431,20,2)
# Cand 28: Len=35.1, Angle=8.1, Straight=0.07, RCY=0.51, RCX=0.44, BBox=(415,647,18,4)
# Cand 29: Len=35.8, Angle=90.0, Straight=0.03, RCY=0.46, RCX=0.75, BBox=(720,586,2,36)
# Cand 30: Len=36.5, Angle=143.1, Straight=0.13, RCY=0.08, RCX=0.62, BBox=(593,96,15,11)
# Cand 31: Len=37.0, Angle=19.4, Straight=0.14, RCY=0.62, RCX=0.36, BBox=(334,790,18,8)
# Cand 32: Len=37.0, Angle=166.0, Straight=0.50, RCY=0.48, RCX=0.38, BBox=(360,607,13,9)
# Cand 33: Len=37.8, Angle=21.0, Straight=0.10, RCY=0.58, RCX=0.33, BBox=(309,734,18,9)
# Cand 34: Len=39.0, Angle=56.3, Straight=0.38, RCY=0.60, RCX=0.50, BBox=(475,766,11,12)
# Cand 35: Len=39.1, Angle=106.4, Straight=0.08, RCY=0.64, RCX=0.26, BBox=(249,804,6,19)
# Cand 36: Len=39.5, Angle=100.0, Straight=0.05, RCY=0.84, RCX=0.76, BBox=(732,1063,4,21)
# Cand 37: Len=39.6, Angle=70.3, Straight=0.08, RCY=0.70, RCX=0.51, BBox=(489,882,7,19)
# Cand 38: Len=40.8, Angle=70.7, Straight=0.08, RCY=0.65, RCX=0.53, BBox=(500,826,8,21)
# Cand 39: Len=41.3, Angle=12.1, Straight=0.08, RCY=0.95, RCX=0.41, BBox=(379,1209,21,5)
# Cand 40: Len=42.3, Angle=73.3, Straight=0.28, RCY=0.08, RCX=0.56, BBox=(535,89,8,22)
# Cand 41: Len=42.6, Angle=25.0, Straight=0.08, RCY=0.55, RCX=0.40, BBox=(370,702,20,9)
# Cand 42: Len=43.6, Angle=21.0, Straight=0.25, RCY=0.49, RCX=0.50, BBox=(476,625,18,8)
# Cand 43: Len=44.3, Angle=32.5, Straight=0.10, RCY=0.72, RCX=0.72, BBox=(677,918,20,11)
# Cand 44: Len=45.0, Angle=15.9, Straight=0.06, RCY=0.42, RCX=0.47, BBox=(439,541,22,7)
# Cand 45: Len=45.6, Angle=165.1, Straight=0.05, RCY=0.42, RCX=0.37, BBox=(340,533,22,7)
# Cand 46: Len=45.9, Angle=32.7, Straight=0.07, RCY=0.59, RCX=0.72, BBox=(695,760,19,14)
# Cand 47: Len=54.8, Angle=92.2, Straight=0.33, RCY=0.67, RCX=0.63, BBox=(603,844,10,27)
# Cand 48: Len=54.9, Angle=35.5, Straight=0.45, RCY=0.48, RCX=0.35, BBox=(334,610,15,16)
# Cand 49: Len=56.5, Angle=7.4, Straight=0.06, RCY=0.27, RCX=0.51, BBox=(471,347,32,4)
# Cand 50: Len=57.0, Angle=122.9, Straight=0.07, RCY=0.85, RCX=0.25, BBox=(235,1072,16,24)
# Cand 51: Len=57.6, Angle=34.8, Straight=0.08, RCY=0.70, RCX=0.64, BBox=(601,887,24,17)
# Cand 52: Len=57.7, Angle=24.8, Straight=0.17, RCY=0.57, RCX=0.42, BBox=(391,715,25,14)
# Cand 53: Len=59.2, Angle=167.0, Straight=0.18, RCY=0.47, RCX=0.36, BBox=(326,599,25,9)
# Cand 54: Len=60.7, Angle=3.6, Straight=0.03, RCY=0.38, RCX=0.49, BBox=(456,488,32,3)
# Cand 55: Len=61.0, Angle=0.0, Straight=0.00, RCY=0.69, RCX=0.78, BBox=(752,846,1,62)
# Cand 56: Len=62.4, Angle=36.5, Straight=0.10, RCY=0.59, RCX=0.74, BBox=(694,750,25,18)
# Cand 57: Len=63.6, Angle=27.4, Straight=0.07, RCY=0.68, RCX=0.40, BBox=(369,865,29,15)
# Cand 58: Len=63.8, Angle=54.8, Straight=0.25, RCY=0.58, RCX=0.45, BBox=(419,729,17,21)
# Cand 59: Len=73.8, Angle=55.0, Straight=0.30, RCY=0.48, RCX=0.37, BBox=(343,607,17,21)
# Cand 60: Len=77.1, Angle=110.1, Straight=0.23, RCY=0.01, RCX=0.11, BBox=(98,0,12,32)
# Cand 61: Len=78.9, Angle=90.0, Straight=0.44, RCY=0.97, RCX=0.76, BBox=(722,1229,9,19)
# Cand 62: Len=81.6, Angle=111.3, Straight=0.09, RCY=0.84, RCX=0.47, BBox=(445,1053,15,37)
# Cand 63: Len=87.1, Angle=31.0, Straight=0.20, RCY=0.48, RCX=0.49, BBox=(446,591,31,22)
# Cand 64: Len=90.6, Angle=149.7, Straight=0.09, RCY=0.93, RCX=0.46, BBox=(425,1184,42,25)
# Cand 65: Len=92.4, Angle=95.5, Straight=0.06, RCY=0.89, RCX=0.76, BBox=(728,1105,5,50)
# Cand 66: Len=93.6, Angle=78.7, Straight=0.18, RCY=0.47, RCX=0.56, BBox=(537,588,9,33)
# Cand 67: Len=102.0, Angle=11.3, Straight=0.14, RCY=0.42, RCX=0.69, BBox=(648,536,40,11)
# Cand 68: Len=104.5, Angle=171.0, Straight=0.06, RCY=0.26, RCX=0.48, BBox=(429,336,55,8)
# Cand 69: Len=104.9, Angle=120.8, Straight=0.15, RCY=0.63, RCX=0.23, BBox=(206,785,26,43)
# Cand 70: Len=112.9, Angle=43.8, Straight=0.46, RCY=0.40, RCX=0.71, BBox=(660,508,34,24)
# Cand 71: Len=113.0, Angle=73.7, Straight=0.04, RCY=0.68, RCX=0.54, BBox=(507,850,16,52)
# Cand 72: Len=116.5, Angle=63.9, Straight=0.06, RCY=0.62, RCX=0.44, BBox=(412,765,25,50)
# Cand 73: Len=119.3, Angle=170.9, Straight=0.08, RCY=0.51, RCX=0.20, BBox=(145,654,57,11)
# Cand 74: Len=122.3, Angle=4.0, Straight=0.08, RCY=0.26, RCX=0.49, BBox=(444,326,62,7)
# Cand 75: Len=123.4, Angle=29.9, Straight=0.09, RCY=0.55, RCX=0.40, BBox=(363,687,50,28)
# Cand 76: Len=130.0, Angle=1.3, Straight=0.17, RCY=0.29, RCX=0.50, BBox=(439,361,55,11)
# Cand 77: Len=131.7, Angle=179.1, Straight=0.07, RCY=0.53, RCX=0.17, BBox=(136,674,63,6)
# Cand 78: Len=133.9, Angle=170.3, Straight=0.25, RCY=0.41, RCX=0.48, BBox=(449,516,44,14)
# Cand 79: Len=135.3, Angle=57.5, Straight=0.53, RCY=0.49, RCX=0.34, BBox=(322,616,20,30)
# Cand 80: Len=140.5, Angle=94.1, Straight=0.04, RCY=0.78, RCX=0.49, BBox=(462,965,8,69)
# Cand 81: Len=164.3, Angle=16.2, Straight=0.25, RCY=0.59, RCX=0.60, BBox=(555,744,55,24)
# Cand 82: Len=206.2, Angle=3.1, Straight=0.20, RCY=0.28, RCX=0.38, BBox=(333,354,58,13)
# Cand 83: Len=209.2, Angle=57.4, Straight=0.48, RCY=0.50, RCX=0.50, BBox=(451,613,56,51)
# Cand 84: Len=221.0, Angle=62.0, Straight=0.07, RCY=0.60, RCX=0.40, BBox=(380,751,45,88)
# Cand 85: Len=232.5, Angle=7.1, Straight=0.58, RCY=0.97, RCX=0.74, BBox=(687,1226,33,22)
# Cand 86: Len=287.5, Angle=54.1, Straight=0.50, RCY=0.91, RCX=0.95, BBox=(889,1159,43,60)
# Cand 87: Len=297.3, Angle=44.0, Straight=0.02, RCY=0.65, RCX=0.56, BBox=(488,779,105,102)
# Cand 88: Len=367.2, Angle=89.3, Straight=0.08, RCY=0.68, RCX=0.12, BBox=(111,763,15,173)
# Cand 89: Len=462.4, Angle=128.2, Straight=0.87, RCY=0.35, RCX=0.59, BBox=(532,415,64,65)
# Cand 90: Len=474.4, Angle=39.3, Straight=0.11, RCY=0.56, RCX=0.52, BBox=(433,642,130,104)
# Cand 91: Len=997.0, Angle=69.4, Straight=0.14, RCY=0.83, RCX=0.19, BBox=(131,945,147,333)
# Head line candidate found (ID: 90). Relative CY: 0.56
#
# --- Final Classification Results ---
# Heart Line: NOT FOUND
# Life Line: NOT FOUND
#
# --- Remaining unclassified lines (potential missed main lines or noise): ---
# Unclassified Cand 0: Len=20.9, Angle=161.6, Straight=0.52, RCY=0.46, RCX=0.35, BBox=(332,585,7,6)
# Unclassified Cand 1: Len=21.3, Angle=116.6, Straight=0.16, RCY=0.72, RCX=0.15, BBox=(142,912,6,11)
# Unclassified Cand 2: Len=21.6, Angle=35.0, Straight=0.07, RCY=0.59, RCX=0.47, BBox=(450,750,11,8)
# Unclassified Cand 3: Len=22.1, Angle=29.7, Straight=0.06, RCY=0.64, RCX=0.37, BBox=(350,819,11,7)
# Unclassified Cand 4: Len=22.4, Angle=39.8, Straight=0.06, RCY=0.58, RCX=0.46, BBox=(435,739,10,8)
# Unclassified Cand 5: Len=22.7, Angle=77.5, Straight=0.08, RCY=0.59, RCX=0.54, BBox=(514,754,3,14)
# Unclassified Cand 6: Len=22.8, Angle=85.6, Straight=0.05, RCY=0.35, RCX=0.75, BBox=(719,434,2,18)
# Unclassified Cand 7: Len=23.0, Angle=0.0, Straight=0.00, RCY=0.92, RCX=0.97, BBox=(930,1162,1,24)
# Unclassified Cand 8: Len=23.1, Angle=15.3, Straight=0.31, RCY=0.41, RCX=0.68, BBox=(643,527,12,6)
# Unclassified Cand 9: Len=23.8, Angle=84.3, Straight=0.06, RCY=0.52, RCX=0.63, BBox=(600,654,2,17)
# Unclassified Cand 10: Len=24.0, Angle=59.0, Straight=0.07, RCY=0.71, RCX=0.55, BBox=(523,904,7,11)
# Unclassified Cand 11: Len=24.1, Angle=130.6, Straight=0.15, RCY=0.82, RCX=0.29, BBox=(270,1043,9,10)
# Unclassified Cand 12: Len=24.7, Angle=14.0, Straight=0.22, RCY=0.09, RCX=0.64, BBox=(604,111,13,6)
# Unclassified Cand 13: Len=25.2, Angle=40.6, Straight=0.05, RCY=0.76, RCX=0.35, BBox=(335,968,11,9)
# Unclassified Cand 14: Len=26.4, Angle=84.3, Straight=0.52, RCY=0.50, RCX=0.44, BBox=(424,633,7,11)
# Unclassified Cand 15: Len=26.6, Angle=48.0, Straight=0.10, RCY=0.73, RCX=0.43, BBox=(407,928,10,11)
# Unclassified Cand 16: Len=27.1, Angle=9.5, Straight=0.11, RCY=0.59, RCX=0.32, BBox=(300,753,14,4)
# Unclassified Cand 17: Len=27.7, Angle=8.1, Straight=0.06, RCY=0.59, RCX=0.66, BBox=(629,749,16,3)
# Unclassified Cand 18: Len=29.3, Angle=116.6, Straight=0.20, RCY=0.41, RCX=0.65, BBox=(625,522,7,13)
# Unclassified Cand 19: Len=29.5, Angle=169.7, Straight=0.09, RCY=0.23, RCX=0.57, BBox=(540,288,19,4)
# Unclassified Cand 20: Len=29.7, Angle=94.8, Straight=0.06, RCY=0.82, RCX=0.77, BBox=(736,1039,3,16)
# Unclassified Cand 21: Len=30.1, Angle=20.6, Straight=0.08, RCY=0.59, RCX=0.64, BBox=(607,754,15,6)
# Unclassified Cand 22: Len=30.5, Angle=77.5, Straight=0.09, RCY=0.61, RCX=0.54, BBox=(517,771,4,16)
# Unclassified Cand 23: Len=30.7, Angle=174.3, Straight=0.06, RCY=0.28, RCX=0.47, BBox=(444,355,22,3)
# Unclassified Cand 24: Len=31.6, Angle=68.2, Straight=0.59, RCY=0.99, RCX=0.24, BBox=(233,1264,9,11)
# Unclassified Cand 25: Len=32.0, Angle=9.5, Straight=0.35, RCY=0.49, RCX=0.46, BBox=(434,621,13,6)
# Unclassified Cand 26: Len=33.2, Angle=61.7, Straight=0.08, RCY=0.63, RCX=0.47, BBox=(450,796,9,15)
# Unclassified Cand 27: Len=33.8, Angle=4.1, Straight=0.05, RCY=0.34, RCX=0.61, BBox=(574,431,20,2)
# Unclassified Cand 28: Len=35.1, Angle=8.1, Straight=0.07, RCY=0.51, RCX=0.44, BBox=(415,647,18,4)
# Unclassified Cand 29: Len=35.8, Angle=90.0, Straight=0.03, RCY=0.46, RCX=0.75, BBox=(720,586,2,36)
# Unclassified Cand 30: Len=36.5, Angle=143.1, Straight=0.13, RCY=0.08, RCX=0.62, BBox=(593,96,15,11)
# Unclassified Cand 31: Len=37.0, Angle=19.4, Straight=0.14, RCY=0.62, RCX=0.36, BBox=(334,790,18,8)
# Unclassified Cand 32: Len=37.0, Angle=166.0, Straight=0.50, RCY=0.48, RCX=0.38, BBox=(360,607,13,9)
# Unclassified Cand 33: Len=37.8, Angle=21.0, Straight=0.10, RCY=0.58, RCX=0.33, BBox=(309,734,18,9)
# Unclassified Cand 34: Len=39.0, Angle=56.3, Straight=0.38, RCY=0.60, RCX=0.50, BBox=(475,766,11,12)
# Unclassified Cand 35: Len=39.1, Angle=106.4, Straight=0.08, RCY=0.64, RCX=0.26, BBox=(249,804,6,19)
# Unclassified Cand 36: Len=39.5, Angle=100.0, Straight=0.05, RCY=0.84, RCX=0.76, BBox=(732,1063,4,21)
# Unclassified Cand 37: Len=39.6, Angle=70.3, Straight=0.08, RCY=0.70, RCX=0.51, BBox=(489,882,7,19)
# Unclassified Cand 38: Len=40.8, Angle=70.7, Straight=0.08, RCY=0.65, RCX=0.53, BBox=(500,826,8,21)
# Unclassified Cand 39: Len=41.3, Angle=12.1, Straight=0.08, RCY=0.95, RCX=0.41, BBox=(379,1209,21,5)
# Unclassified Cand 40: Len=42.3, Angle=73.3, Straight=0.28, RCY=0.08, RCX=0.56, BBox=(535,89,8,22)
# Unclassified Cand 41: Len=42.6, Angle=25.0, Straight=0.08, RCY=0.55, RCX=0.40, BBox=(370,702,20,9)
# Unclassified Cand 42: Len=43.6, Angle=21.0, Straight=0.25, RCY=0.49, RCX=0.50, BBox=(476,625,18,8)
# Unclassified Cand 43: Len=44.3, Angle=32.5, Straight=0.10, RCY=0.72, RCX=0.72, BBox=(677,918,20,11)
# Unclassified Cand 44: Len=45.0, Angle=15.9, Straight=0.06, RCY=0.42, RCX=0.47, BBox=(439,541,22,7)
# Unclassified Cand 45: Len=45.6, Angle=165.1, Straight=0.05, RCY=0.42, RCX=0.37, BBox=(340,533,22,7)
# Unclassified Cand 46: Len=45.9, Angle=32.7, Straight=0.07, RCY=0.59, RCX=0.72, BBox=(695,760,19,14)
# Unclassified Cand 47: Len=54.8, Angle=92.2, Straight=0.33, RCY=0.67, RCX=0.63, BBox=(603,844,10,27)
# Unclassified Cand 48: Len=54.9, Angle=35.5, Straight=0.45, RCY=0.48, RCX=0.35, BBox=(334,610,15,16)
# Unclassified Cand 49: Len=56.5, Angle=7.4, Straight=0.06, RCY=0.27, RCX=0.51, BBox=(471,347,32,4)
# Unclassified Cand 50: Len=57.0, Angle=122.9, Straight=0.07, RCY=0.85, RCX=0.25, BBox=(235,1072,16,24)
# Unclassified Cand 51: Len=57.6, Angle=34.8, Straight=0.08, RCY=0.70, RCX=0.64, BBox=(601,887,24,17)
# Unclassified Cand 52: Len=57.7, Angle=24.8, Straight=0.17, RCY=0.57, RCX=0.42, BBox=(391,715,25,14)
# Unclassified Cand 53: Len=59.2, Angle=167.0, Straight=0.18, RCY=0.47, RCX=0.36, BBox=(326,599,25,9)
# Unclassified Cand 54: Len=60.7, Angle=3.6, Straight=0.03, RCY=0.38, RCX=0.49, BBox=(456,488,32,3)
# Unclassified Cand 55: Len=61.0, Angle=0.0, Straight=0.00, RCY=0.69, RCX=0.78, BBox=(752,846,1,62)
# Unclassified Cand 56: Len=62.4, Angle=36.5, Straight=0.10, RCY=0.59, RCX=0.74, BBox=(694,750,25,18)
# Unclassified Cand 57: Len=63.6, Angle=27.4, Straight=0.07, RCY=0.68, RCX=0.40, BBox=(369,865,29,15)
# Unclassified Cand 58: Len=63.8, Angle=54.8, Straight=0.25, RCY=0.58, RCX=0.45, BBox=(419,729,17,21)
# Unclassified Cand 59: Len=73.8, Angle=55.0, Straight=0.30, RCY=0.48, RCX=0.37, BBox=(343,607,17,21)
# Unclassified Cand 60: Len=77.1, Angle=110.1, Straight=0.23, RCY=0.01, RCX=0.11, BBox=(98,0,12,32)
# Unclassified Cand 61: Len=78.9, Angle=90.0, Straight=0.44, RCY=0.97, RCX=0.76, BBox=(722,1229,9,19)
# Unclassified Cand 62: Len=81.6, Angle=111.3, Straight=0.09, RCY=0.84, RCX=0.47, BBox=(445,1053,15,37)
# Unclassified Cand 63: Len=87.1, Angle=31.0, Straight=0.20, RCY=0.48, RCX=0.49, BBox=(446,591,31,22)
# Unclassified Cand 64: Len=90.6, Angle=149.7, Straight=0.09, RCY=0.93, RCX=0.46, BBox=(425,1184,42,25)
# Unclassified Cand 65: Len=92.4, Angle=95.5, Straight=0.06, RCY=0.89, RCX=0.76, BBox=(728,1105,5,50)
# Unclassified Cand 66: Len=93.6, Angle=78.7, Straight=0.18, RCY=0.47, RCX=0.56, BBox=(537,588,9,33)
# Unclassified Cand 67: Len=102.0, Angle=11.3, Straight=0.14, RCY=0.42, RCX=0.69, BBox=(648,536,40,11)
# Unclassified Cand 68: Len=104.5, Angle=171.0, Straight=0.06, RCY=0.26, RCX=0.48, BBox=(429,336,55,8)
# Unclassified Cand 69: Len=104.9, Angle=120.8, Straight=0.15, RCY=0.63, RCX=0.23, BBox=(206,785,26,43)
# Unclassified Cand 70: Len=112.9, Angle=43.8, Straight=0.46, RCY=0.40, RCX=0.71, BBox=(660,508,34,24)
# Unclassified Cand 71: Len=113.0, Angle=73.7, Straight=0.04, RCY=0.68, RCX=0.54, BBox=(507,850,16,52)
# Unclassified Cand 72: Len=116.5, Angle=63.9, Straight=0.06, RCY=0.62, RCX=0.44, BBox=(412,765,25,50)
# Unclassified Cand 73: Len=119.3, Angle=170.9, Straight=0.08, RCY=0.51, RCX=0.20, BBox=(145,654,57,11)
# Unclassified Cand 74: Len=122.3, Angle=4.0, Straight=0.08, RCY=0.26, RCX=0.49, BBox=(444,326,62,7)
# Unclassified Cand 75: Len=123.4, Angle=29.9, Straight=0.09, RCY=0.55, RCX=0.40, BBox=(363,687,50,28)
# Unclassified Cand 76: Len=130.0, Angle=1.3, Straight=0.17, RCY=0.29, RCX=0.50, BBox=(439,361,55,11)
# Unclassified Cand 77: Len=131.7, Angle=179.1, Straight=0.07, RCY=0.53, RCX=0.17, BBox=(136,674,63,6)
# Unclassified Cand 78: Len=133.9, Angle=170.3, Straight=0.25, RCY=0.41, RCX=0.48, BBox=(449,516,44,14)
# Unclassified Cand 79: Len=135.3, Angle=57.5, Straight=0.53, RCY=0.49, RCX=0.34, BBox=(322,616,20,30)
# Unclassified Cand 80: Len=140.5, Angle=94.1, Straight=0.04, RCY=0.78, RCX=0.49, BBox=(462,965,8,69)
# Unclassified Cand 81: Len=164.3, Angle=16.2, Straight=0.25, RCY=0.59, RCX=0.60, BBox=(555,744,55,24)
# Unclassified Cand 82: Len=206.2, Angle=3.1, Straight=0.20, RCY=0.28, RCX=0.38, BBox=(333,354,58,13)
# Unclassified Cand 83: Len=209.2, Angle=57.4, Straight=0.48, RCY=0.50, RCX=0.50, BBox=(451,613,56,51)
# Unclassified Cand 84: Len=221.0, Angle=62.0, Straight=0.07, RCY=0.60, RCX=0.40, BBox=(380,751,45,88)
# Unclassified Cand 85: Len=232.5, Angle=7.1, Straight=0.58, RCY=0.97, RCX=0.74, BBox=(687,1226,33,22)
# Unclassified Cand 86: Len=287.5, Angle=54.1, Straight=0.50, RCY=0.91, RCX=0.95, BBox=(889,1159,43,60)
# Unclassified Cand 87: Len=297.3, Angle=44.0, Straight=0.02, RCY=0.65, RCX=0.56, BBox=(488,779,105,102)
# Unclassified Cand 88: Len=367.2, Angle=89.3, Straight=0.08, RCY=0.68, RCX=0.12, BBox=(111,763,15,173)
# Unclassified Cand 89: Len=462.4, Angle=128.2, Straight=0.87, RCY=0.35, RCX=0.59, BBox=(532,415,64,65)
# Unclassified Cand 91: Len=997.0, Angle=69.4, Straight=0.14, RCY=0.83, RCX=0.19, BBox=(131,945,147,333)

# %% [markdown]
# Below is custom by me

# %%
import cv2
import numpy as np
import mediapipe as mp
from skimage.morphology import skeletonize
from skimage.filters import meijering
from skimage.util import img_as_ubyte
import matplotlib.pyplot as plt

def process_image(image_path):
    """
    Processes a hand image to extract and identify the Heart, Head, and Life lines.
    This version includes refined pre-processing and classification heuristics for improved robustness.

    Args:
        image_path (str): The path to the input hand image.
    """
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Image not loaded from {image_path}. Check path or format.")
        return

    print(f"Processing image: {image_path}")

    # --- 1. Robust Background Removal using MediaPipe ---
    # This helps in isolating the hand regardless of skin tone or complex backgrounds.
    mp_selfie_segmentation = mp.solutions.selfie_segmentation
    with mp_selfie_segmentation.SelfieSegmentation(model_selection=1) as segmentor:
        rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        result = segmentor.process(rgb_img)
        mask = result.segmentation_mask

        # Apply a Gaussian blur to the mask to smooth edges
        # Reduced blur slightly from default 15x15 to 11x11, as per your change
        mask = cv2.GaussianBlur(mask, (11, 11), 0) 

        # Create a 3-channel mask for element-wise multiplication
        mask_3ch = np.stack([mask] * 3, axis=-1)

        # Threshold the mask to create a binary mask of the hand (foreground)
        # Using 0.1 for more inclusive hand segmentation.
        hand_mask_binary = (mask_3ch > 0.1).astype(np.uint8)

        # Create a white background for the output image
        white_bg = np.ones_like(img, dtype=np.uint8) * 255

        # Apply the mask: hand remains, background becomes white
        img_no_bg = (img * hand_mask_binary + white_bg * (1 - hand_mask_binary)).astype(np.uint8)

    # --- 2. Line Enhancement Filters ---
    gray = cv2.cvtColor(img_no_bg, cv2.COLOR_BGR2GRAY)

    # --- Global Histogram Equalization ---
    # This step helps to normalize the overall brightness and contrast
    # across different images, making subsequent processing more consistent.
    equalized_gray = cv2.equalizeHist(gray)

    # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization) for better contrast
    # CLAHE is applied AFTER global equalization for local fine-tuning.
    clahe = cv2.createCLAHE(clipLimit=3, tileGridSize=(8, 8)) # Your adjusted tile size
    enhanced = clahe.apply(equalized_gray) # Apply CLAHE to the globally equalized image

    # Apply Top-Hat transform to highlight bright features (lines) on a dark background
    kernel_tophat = cv2.getStructuringElement(cv2.MORPH_RECT, (30, 30))
    tophat = cv2.morphologyEx(enhanced, cv2.MORPH_TOPHAT, kernel_tophat)
    
    # Combine enhanced image with tophat result for overall line prominence
    # Adjusted weights to give slightly more prominence to the 'tophat' features
    combined = cv2.addWeighted(enhanced, 0.6, tophat, 0.4, 0) # Adjusted weights

    # Meijering filter: specializes in detecting vessel-like (line-like) structures
    meij = meijering(combined / 255.0, sigmas=range(1, 10), black_ridges=True) 
    meij = img_as_ubyte(meij)

    # Adaptive Thresholding: Use OTSU's method.
    _, binary = cv2.threshold(meij, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    # Debug visualization for thresholding result
    # cv2.imshow("Debug: Binary Image after OTSU", binary)

    # Skeletonization: Reduces lines to 1-pixel width, simplifying contour analysis
    skeleton = skeletonize(binary // 255) 
    skeleton = (skeleton * 255).astype(np.uint8)

    # --- 3. Morphological Closing ---
    kernel_close = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    # Can increase iterations if lines are very broken, but be careful of merging separate lines.
    closed = cv2.morphologyEx(skeleton, cv2.MORPH_CLOSE, kernel_close, iterations=1) 
    
    # Debug visualization for line connectivity
    # cv2.imshow("Debug: Closed Image (Lines Connected)", closed)

    # --- 4. Line Detection (Contours) ---
    contours, _ = cv2.findContours(closed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    height, width = gray.shape

    # --- 5. Filter Longest and Smallest Lines ---
    filtered_contours = []
    if contours:
        contour_lengths = [cv2.arcLength(c, False) for c in contours]

        # Dynamic length thresholds based on image dimensions
        # Tuned `min_length_ratio` lower to capture more fragmented main lines
        min_length_ratio = 0.01 # Adjusted
        max_length_ratio = 0.80  

        min_length_threshold = min(height, width) * min_length_ratio
        max_length_threshold = max(height, width) * max_length_ratio

        print(f"\nInitial contours found: {len(contours)}")
        print(f"Length thresholds: Min={min_length_threshold:.2f}, Max={max_length_threshold:.2f}")

        for contour, length in zip(contours, contour_lengths):
            if length > min_length_threshold and length < max_length_threshold:
                filtered_contours.append(contour)

        print(f"Contours after length filtering: {len(filtered_contours)}")

        # Optional refinement: remove a few absolute shortest/longest from the remaining
        if len(filtered_contours) > 5:
            filtered_contours.sort(key=lambda c: cv2.arcLength(c, False))
            num_to_remove_shortest = min(1, len(filtered_contours) // 10) 
            filtered_contours = filtered_contours[num_to_remove_shortest:]

    # --- Initialize Variables for the Three Main Lines ---
    heart_line = None
    head_line = None
    life_line = None
    heart_line_data = None 
    head_line_data = None
    life_line_data = None

    # --- 6. Feature Extraction for Classification ---
    line_candidates_info = []
    for i, contour in enumerate(filtered_contours):
        x, y, w, h = cv2.boundingRect(contour)
        
        M = cv2.moments(contour)
        cx, cy = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"])) if M["m00"] != 0 else (x + w // 2, y + h // 2)

        length = cv2.arcLength(contour, False)

        angle = 0
        straightness = 0
        if len(contour) >= 5: # minAreaRect requires at least 5 points
            rect = cv2.minAreaRect(contour)
            center, dims, raw_angle = rect
            
            # Normalize angle to be 0-90 degrees (0 = horizontal, 90 = vertical)
            if dims[0] < dims[1]: 
                angle = 90 + raw_angle
            else: 
                angle = abs(raw_angle)
            
            straightness = min(dims) / max(dims) if max(dims) > 0 else 0
        
        relative_cy = cy / height
        relative_cx = cx / width

        line_candidates_info.append({
            'id': i,
            'contour': contour,
            'bbox': (x, y, w, h),
            'cx': cx, 'cy': cy,
            'relative_cx': relative_cx,
            'relative_cy': relative_cy,
            'length': length,
            'angle': angle, # Angle in degrees (0 = horizontal, 90 = vertical)
            'straightness': straightness, # 1 for very straight, <1 for curved
        })
    
    print(f"\nCandidates for main line classification: {len(line_candidates_info)}")
    for i, lc in enumerate(line_candidates_info):
        print(f"Cand {lc['id']}: Len={lc['length']:.1f}, Angle={lc['angle']:.1f}, Straight={lc['straightness']:.2f}, "
              f"RCY={lc['relative_cy']:.2f}, RCX={lc['relative_cx']:.2f}, BBox=({lc['bbox'][0]},{lc['bbox'][1]},{lc['bbox'][2]},{lc['bbox'][3]})")

    classified_contours_ids = set()

    # --- 7. Heuristic-Based Line Classification ---

    # --- 7.1. Identify Heart Line ---
    heart_candidates = []
    for i, lc in enumerate(line_candidates_info):
        # Increased relative_cy upper bound (0.70) to be more lenient for lower heart lines.
        # Increased angle tolerance (65) to allow for more curved heart lines.
        # Decreased minimum length (0.20) to capture partial or faint heart line segments.
        if lc['relative_cy'] < 0.70 and \
           lc['length'] > width * 0.20 and \
           lc['angle'] < 65: 
            heart_candidates.append(lc)
    
    if heart_candidates:
        heart_candidates.sort(key=lambda x: x['relative_cy'])
        heart_line_data = heart_candidates[0]
        heart_line = heart_line_data['contour']
        classified_contours_ids.add(heart_line_data['id'])
        print(f"Heart line candidate found (ID: {heart_line_data['id']}). Relative CY: {heart_line_data['relative_cy']:.2f}")

    # --- 7.2. Identify Head Line ---
    head_candidates = []
    for i, lc in enumerate(line_candidates_info):
        if lc['id'] not in classified_contours_ids:
            # More strict relative_cy bounds for head line (0.40 to 0.85)
            # Increased minimum length (0.35) for robustness.
            # Slightly tightened angle tolerance (55) for more specific horizontal/slanted lines.
            if lc['relative_cy'] > 0.40 and lc['relative_cy'] < 0.85 and \
               lc['length'] > width * 0.35 and lc['angle'] < 55: # Adjusted angle and length
                # Ensure it's below the heart line if heart line was found
                if heart_line_data is None or lc['relative_cy'] > heart_line_data['relative_cy'] + 0.04:
                    head_candidates.append(lc)
    
    if head_candidates:
        head_candidates.sort(key=lambda x: (x['relative_cy'], -x['length'])) 
        head_line_data = head_candidates[0]
        head_line = head_line_data['contour']
        classified_contours_ids.add(head_line_data['id'])
        print(f"Head line candidate found (ID: {head_line_data['id']}). Relative CY: {head_line_data['relative_cy']:.2f}")


    # --- 7.3. Identify Life Line ---
    life_candidates = []
    for i, lc in enumerate(line_candidates_info):
        if lc['id'] not in classified_contours_ids:
            # Origin point (for a left hand): Top-left region
            # These thresholds are crucial. Tune based on your image set.
            is_origin_in_thumb_base_area = (lc['relative_cx'] < 0.45 and lc['relative_cy'] < 0.50) 
            
            # Shape characteristics: Long, significant vertical and horizontal spread, curved.
            # Life line is usually more vertical/diagonal than heart/head lines.
            is_long_and_curved = (lc['length'] > width * 0.25 and # Lowered minimum length significantly
                                  lc['bbox'][3] > height * 0.25 and # Significant vertical span
                                  lc['bbox'][2] > width * 0.12 and # Significant horizontal span
                                  lc['straightness'] < 0.75 and # Not very straight (more lenient)
                                  lc['angle'] > 25 and lc['angle'] < 75) # More specific angle range for typical curve
            
            # Combine conditions and assign a score for each candidate
            score = 0
            if is_origin_in_thumb_base_area: score += 2 # Strong weight for correct origin
            if is_long_and_curved: score += 3 # Strong weight for shape and length
            
            # Additional score for being among the longest remaining lines
            if lc['length'] > width * 0.40: score += 1
            if lc['bbox'][3] > height * 0.40: score += 1 # Very tall line
            
            if score > 0: # Only consider candidates that meet at least some criteria
                life_candidates.append({'score': score, 'info': lc})

    if life_candidates:
        # Prioritize by highest score, then by length (longer preferred among same scores),
        # then by straightness (more curved preferred)
        life_candidates.sort(key=lambda x: (x['score'], -x['info']['length'], x['info']['straightness']), reverse=True)
        
        life_line_data = life_candidates[0]['info']
        life_line = life_line_data['contour']
        classified_contours_ids.add(life_line_data['id'])
        print(f"Life line candidate found (ID: {life_line_data['id']}). Length: {life_line_data['length']:.1f}, Score: {life_candidates[0]['score']}")
    
    # --- Final Classification Summary ---
    print("\n--- Final Classification Results ---")
    if heart_line is None: print("Heart Line: NOT FOUND")
    if head_line is None: print("Head Line: NOT FOUND")
    if life_line is None: print("Life Line: NOT FOUND")
    
    if len(classified_contours_ids) < 3:
        print("\n--- Remaining unclassified lines (potential missed main lines or noise): ---")
        for lc in line_candidates_info:
            if lc['id'] not in classified_contours_ids:
                print(f"Unclassified Cand {lc['id']}: Len={lc['length']:.1f}, Angle={lc['angle']:.1f}, Straight={lc['straightness']:.2f}, "
                      f"RCY={lc['relative_cy']:.2f}, RCX={lc['relative_cx']:.2f}, BBox=({lc['bbox'][0]},{lc['bbox'][1]},{lc['bbox'][2]},{lc['bbox'][3]})")


    # --- 8. Draw the Identified Lines on the Original Image ---
    three_lines_img_gray = np.zeros((height, width), dtype=np.uint8)
    three_lines_img = cv2.cvtColor(three_lines_img_gray, cv2.COLOR_GRAY2BGR)

    output_on_original = img_no_bg.copy()

    # Draw identified lines in distinct colors
    if heart_line is not None:
        cv2.drawContours(three_lines_img, [heart_line], -1, (0, 0, 255), 2) # Red
        cv2.drawContours(output_on_original, [heart_line], -1, (0, 0, 255), 2)
    if head_line is not None:
        cv2.drawContours(three_lines_img, [head_line], -1, (0, 255, 255), 2) # Yellow
        cv2.drawContours(output_on_original, [head_line], -1, (0, 255, 255), 2)
    if life_line is not None:
        cv2.drawContours(three_lines_img, [life_line], -1, (0, 255, 0), 2) # Green
        cv2.drawContours(output_on_original, [life_line], -1, (0, 255, 0), 2)

    # Display results
    cv2.imshow("Extracted Main Palm Lines (Isolated)", three_lines_img)
    cv2.imshow("Main Lines Overlayed on Hand", output_on_original)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# --- Example Usage ---
# Make sure 'Main Lines Overlayed on Hand.jpg' is in the same directory as this script.
process_image("./image.png")
# Out:
# Processing image: ./image.png
#
# Initial contours found: 550
# Length thresholds: Min=9.60, Max=1024.00
# Contours after length filtering: 158
#
# Candidates for main line classification: 157
# Cand 0: Len=9.8, Angle=0.0, Straight=0.00, RCY=0.59, RCX=0.32, BBox=(301,754,9,2)
# Cand 1: Len=9.8, Angle=180.0, Straight=0.11, RCY=0.57, RCX=0.50, BBox=(478,729,10,2)
# Cand 2: Len=9.8, Angle=9.5, Straight=0.12, RCY=0.51, RCX=0.45, BBox=(424,649,8,2)
# Cand 3: Len=9.8, Angle=166.0, Straight=0.12, RCY=0.48, RCX=0.33, BBox=(316,608,7,2)
# Cand 4: Len=10.0, Angle=0.0, Straight=0.00, RCY=0.32, RCX=0.70, BBox=(671,410,1,11)
# Cand 5: Len=10.0, Angle=0.0, Straight=0.00, RCY=0.28, RCX=0.74, BBox=(715,358,1,11)
# Cand 6: Len=10.0, Angle=0.0, Straight=0.00, RCY=0.02, RCX=0.10, BBox=(99,21,1,11)
# Cand 7: Len=10.2, Angle=76.0, Straight=0.14, RCY=0.55, RCX=0.77, BBox=(735,706,3,6)
# Cand 8: Len=10.2, Angle=18.4, Straight=0.12, RCY=0.50, RCX=0.51, BBox=(485,637,6,3)
# Cand 9: Len=10.2, Angle=166.0, Straight=0.14, RCY=0.41, RCX=0.67, BBox=(643,520,6,3)
# Cand 10: Len=10.2, Angle=146.3, Straight=0.21, RCY=0.28, RCX=0.44, BBox=(426,352,6,3)
# Cand 11: Len=10.2, Angle=123.7, Straight=0.32, RCY=0.22, RCX=0.68, BBox=(648,280,3,6)
# Cand 12: Len=10.5, Angle=0.0, Straight=0.00, RCY=0.60, RCX=0.37, BBox=(350,768,7,8)
# Cand 13: Len=10.7, Angle=18.4, Straight=0.12, RCY=0.64, RCX=0.37, BBox=(352,821,6,3)
# Cand 14: Len=10.7, Angle=123.7, Straight=0.57, RCY=0.48, RCX=0.38, BBox=(362,610,4,5)
# Cand 15: Len=10.8, Angle=0.0, Straight=0.00, RCY=0.52, RCX=0.63, BBox=(600,655,2,10)
# Cand 16: Len=11.0, Angle=0.0, Straight=0.00, RCY=0.89, RCX=0.76, BBox=(728,1128,1,12)
# Cand 17: Len=11.0, Angle=0.0, Straight=0.00, RCY=0.42, RCX=0.35, BBox=(328,532,12,1)
# Cand 18: Len=11.0, Angle=0.0, Straight=0.00, RCY=0.27, RCX=0.74, BBox=(713,339,1,12)
# Cand 19: Len=11.0, Angle=0.0, Straight=0.00, RCY=0.17, RCX=0.51, BBox=(482,223,12,1)
# Cand 20: Len=11.1, Angle=63.4, Straight=0.15, RCY=0.74, RCX=0.35, BBox=(333,939,4,6)
# Cand 21: Len=11.2, Angle=63.4, Straight=0.70, RCY=0.16, RCX=0.50, BBox=(478,208,5,5)
# Cand 22: Len=11.4, Angle=26.6, Straight=0.40, RCY=0.46, RCX=0.35, BBox=(332,585,7,4)
# Cand 23: Len=11.4, Angle=0.0, Straight=0.00, RCY=0.30, RCX=0.39, BBox=(368,381,7,2)
# Cand 24: Len=11.5, Angle=36.9, Straight=0.10, RCY=0.68, RCX=0.33, BBox=(312,867,6,4)
# Cand 25: Len=11.8, Angle=104.0, Straight=0.10, RCY=0.80, RCX=0.77, BBox=(739,1026,2,8)
# Cand 26: Len=12.4, Angle=180.0, Straight=0.75, RCY=0.46, RCX=0.37, BBox=(357,590,5,4)
# Cand 27: Len=13.1, Angle=116.6, Straight=0.07, RCY=0.90, RCX=0.55, BBox=(529,1144,4,7)
# Cand 28: Len=13.4, Angle=0.0, Straight=0.14, RCY=0.26, RCX=0.47, BBox=(445,328,8,2)
# Cand 29: Len=13.5, Angle=128.7, Straight=0.15, RCY=0.72, RCX=0.15, BBox=(142,917,5,6)
# Cand 30: Len=13.5, Angle=26.6, Straight=0.07, RCY=0.53, RCX=0.37, BBox=(354,682,7,4)
# Cand 31: Len=13.8, Angle=20.6, Straight=0.29, RCY=0.28, RCX=0.50, BBox=(472,356,9,4)
# Cand 32: Len=13.9, Angle=31.0, Straight=0.10, RCY=0.59, RCX=0.47, BBox=(448,758,7,5)
# Cand 33: Len=14.0, Angle=0.0, Straight=0.00, RCY=0.33, RCX=0.75, BBox=(718,409,1,15)
# Cand 34: Len=14.0, Angle=0.0, Straight=0.00, RCY=0.17, RCX=0.65, BBox=(622,207,1,15)
# Cand 35: Len=14.7, Angle=116.6, Straight=0.20, RCY=0.91, RCX=0.37, BBox=(357,1159,4,7)
# Cand 36: Len=14.7, Angle=63.4, Straight=0.27, RCY=0.50, RCX=0.50, BBox=(478,634,4,7)
# Cand 37: Len=14.8, Angle=80.5, Straight=0.10, RCY=0.60, RCX=0.54, BBox=(515,759,2,9)
# Cand 38: Len=15.1, Angle=71.6, Straight=0.12, RCY=0.63, RCX=0.47, BBox=(453,801,4,8)
# Cand 39: Len=15.2, Angle=123.7, Straight=0.35, RCY=0.53, RCX=0.70, BBox=(671,672,5,7)
# Cand 40: Len=15.5, Angle=18.4, Straight=0.17, RCY=0.59, RCX=0.64, BBox=(611,756,10,4)
# Cand 41: Len=15.8, Angle=84.3, Straight=0.07, RCY=0.26, RCX=0.74, BBox=(711,325,2,13)
# Cand 42: Len=15.9, Angle=59.0, Straight=0.09, RCY=0.71, RCX=0.55, BBox=(524,907,5,8)
# Cand 43: Len=16.0, Angle=0.0, Straight=0.00, RCY=0.40, RCX=0.67, BBox=(639,513,17,1)
# Cand 44: Len=16.1, Angle=0.0, Straight=0.00, RCY=0.52, RCX=0.32, BBox=(302,663,12,11)
# Cand 45: Len=16.5, Angle=14.0, Straight=0.85, RCY=0.00, RCX=0.11, BBox=(102,2,6,5)
# Cand 46: Len=16.7, Angle=15.9, Straight=0.13, RCY=0.50, RCX=0.52, BBox=(493,640,9,3)
# Cand 47: Len=16.7, Angle=90.0, Straight=0.11, RCY=0.49, RCX=0.26, BBox=(248,625,2,10)
# Cand 48: Len=16.7, Angle=90.0, Straight=0.12, RCY=0.15, RCX=0.38, BBox=(362,194,2,9)
# Cand 49: Len=16.8, Angle=6.3, Straight=0.07, RCY=0.59, RCX=0.69, BBox=(653,756,13,2)
# Cand 50: Len=16.8, Angle=9.5, Straight=0.08, RCY=0.29, RCX=0.40, BBox=(379,364,11,2)
# Cand 51: Len=16.8, Angle=171.9, Straight=0.09, RCY=0.26, RCX=0.49, BBox=(469,336,10,2)
# Cand 52: Len=17.0, Angle=0.0, Straight=0.00, RCY=0.34, RCX=0.68, BBox=(644,434,18,1)
# Cand 53: Len=17.1, Angle=69.4, Straight=0.10, RCY=0.84, RCX=0.54, BBox=(518,1077,4,9)
# Cand 54: Len=17.5, Angle=111.8, Straight=0.09, RCY=0.57, RCX=0.26, BBox=(252,730,4,9)
# Cand 55: Len=17.5, Angle=71.6, Straight=0.07, RCY=0.56, RCX=0.77, BBox=(738,717,4,9)
# Cand 56: Len=17.5, Angle=21.8, Straight=0.09, RCY=0.48, RCX=0.47, BBox=(451,613,9,4)
# Cand 57: Len=17.5, Angle=26.6, Straight=0.67, RCY=0.48, RCX=0.37, BBox=(350,612,6,6)
# Cand 58: Len=17.9, Angle=69.4, Straight=0.41, RCY=0.50, RCX=0.45, BBox=(424,633,7,9)
# Cand 59: Len=18.1, Angle=45.0, Straight=0.75, RCY=0.09, RCX=0.56, BBox=(536,108,8,5)
# Cand 60: Len=18.2, Angle=101.3, Straight=0.09, RCY=0.13, RCX=0.08, BBox=(75,166,3,10)
# Cand 61: Len=18.7, Angle=26.6, Straight=0.83, RCY=0.82, RCX=0.17, BBox=(165,1052,6,7)
# Cand 62: Len=18.7, Angle=31.0, Straight=0.11, RCY=0.68, RCX=0.41, BBox=(387,873,9,6)
# Cand 63: Len=18.8, Angle=81.9, Straight=0.07, RCY=0.78, RCX=0.49, BBox=(465,987,2,13)
# Cand 64: Len=18.8, Angle=171.9, Straight=0.07, RCY=0.50, RCX=0.15, BBox=(140,635,13,2)
# Cand 65: Len=19.5, Angle=18.4, Straight=0.09, RCY=0.92, RCX=0.35, BBox=(335,1177,11,4)
# Cand 66: Len=19.5, Angle=18.4, Straight=0.10, RCY=0.48, RCX=0.49, BBox=(465,608,10,4)
# Cand 67: Len=19.7, Angle=77.5, Straight=0.08, RCY=0.68, RCX=0.53, BBox=(511,860,3,12)
# Cand 68: Len=19.8, Angle=97.1, Straight=0.07, RCY=0.13, RCX=0.65, BBox=(627,161,2,14)
# Cand 69: Len=20.3, Angle=21.8, Straight=0.12, RCY=0.68, RCX=0.39, BBox=(369,865,11,5)
# Cand 70: Len=20.8, Angle=171.9, Straight=0.07, RCY=0.31, RCX=0.39, BBox=(369,395,14,2)
# Cand 71: Len=20.9, Angle=45.0, Straight=0.67, RCY=0.98, RCX=0.96, BBox=(920,1256,7,8)
# Cand 72: Len=21.1, Angle=40.6, Straight=0.40, RCY=0.90, RCX=0.22, BBox=(208,1144,9,7)
# Cand 73: Len=21.5, Angle=6.3, Straight=0.15, RCY=0.59, RCX=0.62, BBox=(586,753,11,3)
# Cand 74: Len=21.7, Angle=8.1, Straight=0.08, RCY=0.59, RCX=0.66, BBox=(631,749,12,3)
# Cand 75: Len=22.0, Angle=48.8, Straight=0.19, RCY=0.99, RCX=0.24, BBox=(234,1267,9,9)
# Cand 76: Len=23.3, Angle=20.6, Straight=0.12, RCY=0.57, RCX=0.44, BBox=(420,731,12,6)
# Cand 77: Len=23.6, Angle=31.0, Straight=0.06, RCY=0.60, RCX=0.48, BBox=(460,766,11,7)
# Cand 78: Len=23.7, Angle=0.0, Straight=0.07, RCY=0.98, RCX=0.26, BBox=(245,1259,15,2)
# Cand 79: Len=23.8, Angle=36.9, Straight=0.05, RCY=0.58, RCX=0.46, BBox=(435,739,11,9)
# Cand 80: Len=24.0, Angle=0.0, Straight=0.00, RCY=0.18, RCX=0.65, BBox=(621,223,1,25)
# Cand 81: Len=24.3, Angle=41.2, Straight=0.25, RCY=0.58, RCX=0.45, BBox=(428,741,9,8)
# Cand 82: Len=24.7, Angle=82.9, Straight=0.07, RCY=0.60, RCX=0.78, BBox=(747,767,3,14)
# Cand 83: Len=25.6, Angle=40.6, Straight=0.05, RCY=0.72, RCX=0.72, BBox=(683,920,11,9)
# Cand 84: Len=25.6, Angle=135.0, Straight=0.06, RCY=0.96, RCX=0.48, BBox=(458,1229,10,10)
# Cand 85: Len=25.7, Angle=99.5, Straight=0.12, RCY=0.86, RCX=0.15, BBox=(139,1088,4,14)
# Cand 86: Len=25.8, Angle=84.8, Straight=0.06, RCY=0.57, RCX=0.77, BBox=(742,729,2,15)
# Cand 87: Len=25.9, Angle=39.8, Straight=0.35, RCY=0.49, RCX=0.50, BBox=(476,625,11,7)
# Cand 88: Len=26.3, Angle=20.0, Straight=0.26, RCY=0.41, RCX=0.68, BBox=(643,526,12,6)
# Cand 89: Len=26.5, Angle=0.0, Straight=0.44, RCY=0.48, RCX=0.35, BBox=(337,609,10,5)
# Cand 90: Len=29.2, Angle=35.5, Straight=0.07, RCY=0.62, RCX=0.36, BBox=(334,788,15,11)
# Cand 91: Len=30.7, Angle=174.3, Straight=0.06, RCY=0.28, RCX=0.47, BBox=(444,355,22,3)
# Cand 92: Len=31.2, Angle=50.2, Straight=0.09, RCY=0.49, RCX=0.49, BBox=(463,619,13,14)
# Cand 93: Len=31.5, Angle=127.9, Straight=0.04, RCY=0.85, RCX=0.25, BBox=(235,1082,11,14)
# Cand 94: Len=31.5, Angle=85.9, Straight=0.11, RCY=0.51, RCX=0.50, BBox=(481,642,3,16)
# Cand 95: Len=32.5, Angle=12.5, Straight=0.09, RCY=0.51, RCX=0.46, BBox=(433,656,17,5)
# Cand 96: Len=33.3, Angle=127.6, Straight=0.08, RCY=0.82, RCX=0.29, BBox=(269,1041,11,14)
# Cand 97: Len=33.7, Angle=96.3, Straight=0.05, RCY=0.79, RCX=0.77, BBox=(741,1005,3,20)
# Cand 98: Len=34.6, Angle=129.3, Straight=0.13, RCY=0.68, RCX=0.18, BBox=(163,859,12,14)
# Cand 99: Len=35.5, Angle=78.7, Straight=0.08, RCY=0.61, RCX=0.54, BBox=(517,770,4,19)
# Cand 100: Len=36.4, Angle=72.6, Straight=0.18, RCY=0.67, RCX=0.63, BBox=(603,852,7,17)
# Cand 101: Len=36.9, Angle=90.0, Straight=0.20, RCY=0.51, RCX=0.00, BBox=(0,640,4,16)
# Cand 102: Len=37.1, Angle=74.7, Straight=0.05, RCY=0.69, RCX=0.54, BBox=(514,875,6,19)
# Cand 103: Len=37.6, Angle=72.6, Straight=0.09, RCY=0.65, RCX=0.52, BBox=(500,827,7,18)
# Cand 104: Len=37.8, Angle=18.4, Straight=0.12, RCY=0.57, RCX=0.33, BBox=(309,734,18,8)
# Cand 105: Len=38.6, Angle=39.3, Straight=0.15, RCY=0.60, RCX=0.74, BBox=(698,753,16,11)
# Cand 106: Len=38.8, Angle=93.6, Straight=0.04, RCY=0.31, RCX=0.75, BBox=(717,385,2,23)
# Cand 107: Len=38.9, Angle=139.8, Straight=0.14, RCY=0.08, RCX=0.62, BBox=(593,94,15,13)
# Cand 108: Len=41.7, Angle=96.0, Straight=0.05, RCY=0.15, RCX=0.65, BBox=(623,184,3,22)
# Cand 109: Len=42.5, Angle=8.1, Straight=0.39, RCY=0.42, RCX=0.71, BBox=(675,535,17,8)
# Cand 110: Len=42.9, Angle=3.8, Straight=0.13, RCY=0.28, RCX=0.36, BBox=(337,362,21,4)
# Cand 111: Len=44.5, Angle=0.0, Straight=0.04, RCY=0.38, RCX=0.49, BBox=(460,489,25,2)
# Cand 112: Len=44.8, Angle=141.3, Straight=0.05, RCY=0.91, RCX=0.50, BBox=(472,1161,22,18)
# Cand 113: Len=45.0, Angle=48.8, Straight=0.05, RCY=0.68, RCX=0.61, BBox=(576,863,16,18)
# Cand 114: Len=45.1, Angle=156.4, Straight=0.23, RCY=0.47, RCX=0.36, BBox=(326,599,20,9)
# Cand 115: Len=46.0, Angle=11.9, Straight=0.13, RCY=0.28, RCX=0.37, BBox=(354,355,22,6)
# Cand 116: Len=46.1, Angle=100.9, Straight=0.08, RCY=0.77, RCX=0.78, BBox=(744,973,6,27)
# Cand 117: Len=48.1, Angle=165.3, Straight=0.09, RCY=0.27, RCX=0.47, BBox=(436,337,25,6)
# Cand 118: Len=49.1, Angle=48.8, Straight=0.18, RCY=0.47, RCX=0.48, BBox=(446,590,17,18)
# Cand 119: Len=52.4, Angle=15.3, Straight=0.09, RCY=0.95, RCX=0.40, BBox=(373,1206,25,8)
# Cand 120: Len=52.8, Angle=91.7, Straight=0.02, RCY=0.74, RCX=0.78, BBox=(750,929,2,43)
# Cand 121: Len=53.3, Angle=71.6, Straight=0.20, RCY=0.95, RCX=0.98, BBox=(939,1208,9,25)
# Cand 122: Len=54.0, Angle=165.4, Straight=0.08, RCY=0.52, RCX=0.17, BBox=(146,657,27,7)
# Cand 123: Len=56.9, Angle=49.9, Straight=0.04, RCY=0.73, RCX=0.42, BBox=(398,919,21,24)
# Cand 124: Len=58.1, Angle=23.2, Straight=0.22, RCY=0.57, RCX=0.42, BBox=(391,715,23,14)
# Cand 125: Len=59.4, Angle=62.4, Straight=0.06, RCY=0.61, RCX=0.44, BBox=(417,772,14,26)
# Cand 126: Len=60.3, Angle=8.1, Straight=0.06, RCY=0.27, RCX=0.51, BBox=(471,347,32,6)
# Cand 127: Len=63.2, Angle=169.7, Straight=0.28, RCY=0.59, RCX=0.60, BBox=(555,747,25,8)
# Cand 128: Len=63.9, Angle=126.9, Straight=0.05, RCY=0.88, RCX=0.33, BBox=(311,1115,19,26)
# Cand 129: Len=67.6, Angle=14.9, Straight=0.05, RCY=0.42, RCX=0.46, BBox=(429,539,32,9)
# Cand 130: Len=67.8, Angle=18.4, Straight=0.47, RCY=0.23, RCX=0.66, BBox=(620,282,23,15)
# Cand 131: Len=68.7, Angle=143.8, Straight=0.05, RCY=0.61, RCX=0.22, BBox=(195,767,28,20)
# Cand 132: Len=71.8, Angle=88.3, Straight=0.02, RCY=0.47, RCX=0.75, BBox=(720,572,2,53)
# Cand 133: Len=73.3, Angle=14.0, Straight=0.53, RCY=0.49, RCX=0.34, BBox=(322,618,18,13)
# Cand 134: Len=79.0, Angle=76.0, Straight=0.19, RCY=0.89, RCX=0.14, BBox=(134,1118,10,32)
# Cand 135: Len=79.4, Angle=7.8, Straight=0.38, RCY=0.15, RCX=0.49, BBox=(460,191,24,13)
# Cand 136: Len=87.8, Angle=19.7, Straight=0.45, RCY=0.43, RCX=0.70, BBox=(657,540,31,15)
# Cand 137: Len=88.4, Angle=159.3, Straight=0.06, RCY=0.42, RCX=0.37, BBox=(337,527,40,17)
# Cand 138: Len=90.8, Angle=88.6, Straight=0.02, RCY=0.63, RCX=0.78, BBox=(750,782,2,50)
# Cand 139: Len=92.6, Angle=9.5, Straight=0.09, RCY=0.26, RCX=0.50, BBox=(457,326,47,7)
# Cand 140: Len=96.6, Angle=99.5, Straight=0.06, RCY=0.83, RCX=0.76, BBox=(729,1040,9,48)
# Cand 141: Len=97.6, Angle=1.2, Straight=0.05, RCY=0.53, RCX=0.17, BBox=(137,676,48,4)
# Cand 142: Len=104.5, Angle=148.4, Straight=0.11, RCY=0.93, RCX=0.47, BBox=(427,1182,43,27)
# Cand 143: Len=111.1, Angle=46.3, Straight=0.48, RCY=0.40, RCX=0.71, BBox=(662,508,29,25)
# Cand 144: Len=112.8, Angle=1.8, Straight=0.15, RCY=0.41, RCX=0.48, BBox=(449,516,45,8)
# Cand 145: Len=121.0, Angle=30.7, Straight=0.10, RCY=0.55, RCX=0.40, BBox=(362,686,49,29)
# Cand 146: Len=125.1, Angle=63.4, Straight=0.17, RCY=0.10, RCX=0.64, BBox=(603,110,25,50)
# Cand 147: Len=129.2, Angle=1.3, Straight=0.16, RCY=0.29, RCX=0.50, BBox=(438,361,53,10)
# Cand 148: Len=129.8, Angle=78.0, Straight=0.06, RCY=0.47, RCX=0.45, BBox=(422,565,14,62)
# Cand 149: Len=171.3, Angle=88.4, Straight=0.03, RCY=0.36, RCX=0.75, BBox=(716,426,6,114)
# Cand 150: Len=190.1, Angle=104.6, Straight=0.07, RCY=0.82, RCX=0.47, BBox=(443,1005,24,90)
# Cand 151: Len=216.4, Angle=54.3, Straight=0.52, RCY=0.91, RCX=0.94, BBox=(889,1158,43,61)
# Cand 152: Len=231.1, Angle=42.9, Straight=0.03, RCY=0.65, RCX=0.57, BBox=(489,781,83,79)
# Cand 153: Len=241.8, Angle=66.0, Straight=0.09, RCY=0.63, RCX=0.43, BBox=(386,761,40,85)
# Cand 154: Len=369.7, Angle=39.8, Straight=0.14, RCY=0.57, RCX=0.54, BBox=(434,643,126,107)
# Cand 155: Len=488.6, Angle=180.0, Straight=0.28, RCY=0.98, RCX=0.97, BBox=(821,1237,139,39)
# Cand 156: Len=501.0, Angle=31.7, Straight=0.27, RCY=0.54, RCX=0.36, BBox=(290,664,118,90)
# Heart line candidate found (ID: 156). Relative CY: 0.54
# Life line candidate found (ID: 3). Length: 9.8, Score: 2
#
# --- Final Classification Results ---
# Head Line: NOT FOUND
#
# --- Remaining unclassified lines (potential missed main lines or noise): ---
# Unclassified Cand 0: Len=9.8, Angle=0.0, Straight=0.00, RCY=0.59, RCX=0.32, BBox=(301,754,9,2)
# Unclassified Cand 1: Len=9.8, Angle=180.0, Straight=0.11, RCY=0.57, RCX=0.50, BBox=(478,729,10,2)
# Unclassified Cand 2: Len=9.8, Angle=9.5, Straight=0.12, RCY=0.51, RCX=0.45, BBox=(424,649,8,2)
# Unclassified Cand 4: Len=10.0, Angle=0.0, Straight=0.00, RCY=0.32, RCX=0.70, BBox=(671,410,1,11)
# Unclassified Cand 5: Len=10.0, Angle=0.0, Straight=0.00, RCY=0.28, RCX=0.74, BBox=(715,358,1,11)
# Unclassified Cand 6: Len=10.0, Angle=0.0, Straight=0.00, RCY=0.02, RCX=0.10, BBox=(99,21,1,11)
# Unclassified Cand 7: Len=10.2, Angle=76.0, Straight=0.14, RCY=0.55, RCX=0.77, BBox=(735,706,3,6)
# Unclassified Cand 8: Len=10.2, Angle=18.4, Straight=0.12, RCY=0.50, RCX=0.51, BBox=(485,637,6,3)
# Unclassified Cand 9: Len=10.2, Angle=166.0, Straight=0.14, RCY=0.41, RCX=0.67, BBox=(643,520,6,3)
# Unclassified Cand 10: Len=10.2, Angle=146.3, Straight=0.21, RCY=0.28, RCX=0.44, BBox=(426,352,6,3)
# Unclassified Cand 11: Len=10.2, Angle=123.7, Straight=0.32, RCY=0.22, RCX=0.68, BBox=(648,280,3,6)
# Unclassified Cand 12: Len=10.5, Angle=0.0, Straight=0.00, RCY=0.60, RCX=0.37, BBox=(350,768,7,8)
# Unclassified Cand 13: Len=10.7, Angle=18.4, Straight=0.12, RCY=0.64, RCX=0.37, BBox=(352,821,6,3)
# Unclassified Cand 14: Len=10.7, Angle=123.7, Straight=0.57, RCY=0.48, RCX=0.38, BBox=(362,610,4,5)
# Unclassified Cand 15: Len=10.8, Angle=0.0, Straight=0.00, RCY=0.52, RCX=0.63, BBox=(600,655,2,10)
# Unclassified Cand 16: Len=11.0, Angle=0.0, Straight=0.00, RCY=0.89, RCX=0.76, BBox=(728,1128,1,12)
# Unclassified Cand 17: Len=11.0, Angle=0.0, Straight=0.00, RCY=0.42, RCX=0.35, BBox=(328,532,12,1)
# Unclassified Cand 18: Len=11.0, Angle=0.0, Straight=0.00, RCY=0.27, RCX=0.74, BBox=(713,339,1,12)
# Unclassified Cand 19: Len=11.0, Angle=0.0, Straight=0.00, RCY=0.17, RCX=0.51, BBox=(482,223,12,1)
# Unclassified Cand 20: Len=11.1, Angle=63.4, Straight=0.15, RCY=0.74, RCX=0.35, BBox=(333,939,4,6)
# Unclassified Cand 21: Len=11.2, Angle=63.4, Straight=0.70, RCY=0.16, RCX=0.50, BBox=(478,208,5,5)
# Unclassified Cand 22: Len=11.4, Angle=26.6, Straight=0.40, RCY=0.46, RCX=0.35, BBox=(332,585,7,4)
# Unclassified Cand 23: Len=11.4, Angle=0.0, Straight=0.00, RCY=0.30, RCX=0.39, BBox=(368,381,7,2)
# Unclassified Cand 24: Len=11.5, Angle=36.9, Straight=0.10, RCY=0.68, RCX=0.33, BBox=(312,867,6,4)
# Unclassified Cand 25: Len=11.8, Angle=104.0, Straight=0.10, RCY=0.80, RCX=0.77, BBox=(739,1026,2,8)
# Unclassified Cand 26: Len=12.4, Angle=180.0, Straight=0.75, RCY=0.46, RCX=0.37, BBox=(357,590,5,4)
# Unclassified Cand 27: Len=13.1, Angle=116.6, Straight=0.07, RCY=0.90, RCX=0.55, BBox=(529,1144,4,7)
# Unclassified Cand 28: Len=13.4, Angle=0.0, Straight=0.14, RCY=0.26, RCX=0.47, BBox=(445,328,8,2)
# Unclassified Cand 29: Len=13.5, Angle=128.7, Straight=0.15, RCY=0.72, RCX=0.15, BBox=(142,917,5,6)
# Unclassified Cand 30: Len=13.5, Angle=26.6, Straight=0.07, RCY=0.53, RCX=0.37, BBox=(354,682,7,4)
# Unclassified Cand 31: Len=13.8, Angle=20.6, Straight=0.29, RCY=0.28, RCX=0.50, BBox=(472,356,9,4)
# Unclassified Cand 32: Len=13.9, Angle=31.0, Straight=0.10, RCY=0.59, RCX=0.47, BBox=(448,758,7,5)
# Unclassified Cand 33: Len=14.0, Angle=0.0, Straight=0.00, RCY=0.33, RCX=0.75, BBox=(718,409,1,15)
# Unclassified Cand 34: Len=14.0, Angle=0.0, Straight=0.00, RCY=0.17, RCX=0.65, BBox=(622,207,1,15)
# Unclassified Cand 35: Len=14.7, Angle=116.6, Straight=0.20, RCY=0.91, RCX=0.37, BBox=(357,1159,4,7)
# Unclassified Cand 36: Len=14.7, Angle=63.4, Straight=0.27, RCY=0.50, RCX=0.50, BBox=(478,634,4,7)
# Unclassified Cand 37: Len=14.8, Angle=80.5, Straight=0.10, RCY=0.60, RCX=0.54, BBox=(515,759,2,9)
# Unclassified Cand 38: Len=15.1, Angle=71.6, Straight=0.12, RCY=0.63, RCX=0.47, BBox=(453,801,4,8)
# Unclassified Cand 39: Len=15.2, Angle=123.7, Straight=0.35, RCY=0.53, RCX=0.70, BBox=(671,672,5,7)
# Unclassified Cand 40: Len=15.5, Angle=18.4, Straight=0.17, RCY=0.59, RCX=0.64, BBox=(611,756,10,4)
# Unclassified Cand 41: Len=15.8, Angle=84.3, Straight=0.07, RCY=0.26, RCX=0.74, BBox=(711,325,2,13)
# Unclassified Cand 42: Len=15.9, Angle=59.0, Straight=0.09, RCY=0.71, RCX=0.55, BBox=(524,907,5,8)
# Unclassified Cand 43: Len=16.0, Angle=0.0, Straight=0.00, RCY=0.40, RCX=0.67, BBox=(639,513,17,1)
# Unclassified Cand 44: Len=16.1, Angle=0.0, Straight=0.00, RCY=0.52, RCX=0.32, BBox=(302,663,12,11)
# Unclassified Cand 45: Len=16.5, Angle=14.0, Straight=0.85, RCY=0.00, RCX=0.11, BBox=(102,2,6,5)
# Unclassified Cand 46: Len=16.7, Angle=15.9, Straight=0.13, RCY=0.50, RCX=0.52, BBox=(493,640,9,3)
# Unclassified Cand 47: Len=16.7, Angle=90.0, Straight=0.11, RCY=0.49, RCX=0.26, BBox=(248,625,2,10)
# Unclassified Cand 48: Len=16.7, Angle=90.0, Straight=0.12, RCY=0.15, RCX=0.38, BBox=(362,194,2,9)
# Unclassified Cand 49: Len=16.8, Angle=6.3, Straight=0.07, RCY=0.59, RCX=0.69, BBox=(653,756,13,2)
# Unclassified Cand 50: Len=16.8, Angle=9.5, Straight=0.08, RCY=0.29, RCX=0.40, BBox=(379,364,11,2)
# Unclassified Cand 51: Len=16.8, Angle=171.9, Straight=0.09, RCY=0.26, RCX=0.49, BBox=(469,336,10,2)
# Unclassified Cand 52: Len=17.0, Angle=0.0, Straight=0.00, RCY=0.34, RCX=0.68, BBox=(644,434,18,1)
# Unclassified Cand 53: Len=17.1, Angle=69.4, Straight=0.10, RCY=0.84, RCX=0.54, BBox=(518,1077,4,9)
# Unclassified Cand 54: Len=17.5, Angle=111.8, Straight=0.09, RCY=0.57, RCX=0.26, BBox=(252,730,4,9)
# Unclassified Cand 55: Len=17.5, Angle=71.6, Straight=0.07, RCY=0.56, RCX=0.77, BBox=(738,717,4,9)
# Unclassified Cand 56: Len=17.5, Angle=21.8, Straight=0.09, RCY=0.48, RCX=0.47, BBox=(451,613,9,4)
# Unclassified Cand 57: Len=17.5, Angle=26.6, Straight=0.67, RCY=0.48, RCX=0.37, BBox=(350,612,6,6)
# Unclassified Cand 58: Len=17.9, Angle=69.4, Straight=0.41, RCY=0.50, RCX=0.45, BBox=(424,633,7,9)
# Unclassified Cand 59: Len=18.1, Angle=45.0, Straight=0.75, RCY=0.09, RCX=0.56, BBox=(536,108,8,5)
# Unclassified Cand 60: Len=18.2, Angle=101.3, Straight=0.09, RCY=0.13, RCX=0.08, BBox=(75,166,3,10)
# Unclassified Cand 61: Len=18.7, Angle=26.6, Straight=0.83, RCY=0.82, RCX=0.17, BBox=(165,1052,6,7)
# Unclassified Cand 62: Len=18.7, Angle=31.0, Straight=0.11, RCY=0.68, RCX=0.41, BBox=(387,873,9,6)
# Unclassified Cand 63: Len=18.8, Angle=81.9, Straight=0.07, RCY=0.78, RCX=0.49, BBox=(465,987,2,13)
# Unclassified Cand 64: Len=18.8, Angle=171.9, Straight=0.07, RCY=0.50, RCX=0.15, BBox=(140,635,13,2)
# Unclassified Cand 65: Len=19.5, Angle=18.4, Straight=0.09, RCY=0.92, RCX=0.35, BBox=(335,1177,11,4)
# Unclassified Cand 66: Len=19.5, Angle=18.4, Straight=0.10, RCY=0.48, RCX=0.49, BBox=(465,608,10,4)
# Unclassified Cand 67: Len=19.7, Angle=77.5, Straight=0.08, RCY=0.68, RCX=0.53, BBox=(511,860,3,12)
# Unclassified Cand 68: Len=19.8, Angle=97.1, Straight=0.07, RCY=0.13, RCX=0.65, BBox=(627,161,2,14)
# Unclassified Cand 69: Len=20.3, Angle=21.8, Straight=0.12, RCY=0.68, RCX=0.39, BBox=(369,865,11,5)
# Unclassified Cand 70: Len=20.8, Angle=171.9, Straight=0.07, RCY=0.31, RCX=0.39, BBox=(369,395,14,2)
# Unclassified Cand 71: Len=20.9, Angle=45.0, Straight=0.67, RCY=0.98, RCX=0.96, BBox=(920,1256,7,8)
# Unclassified Cand 72: Len=21.1, Angle=40.6, Straight=0.40, RCY=0.90, RCX=0.22, BBox=(208,1144,9,7)
# Unclassified Cand 73: Len=21.5, Angle=6.3, Straight=0.15, RCY=0.59, RCX=0.62, BBox=(586,753,11,3)
# Unclassified Cand 74: Len=21.7, Angle=8.1, Straight=0.08, RCY=0.59, RCX=0.66, BBox=(631,749,12,3)
# Unclassified Cand 75: Len=22.0, Angle=48.8, Straight=0.19, RCY=0.99, RCX=0.24, BBox=(234,1267,9,9)
# Unclassified Cand 76: Len=23.3, Angle=20.6, Straight=0.12, RCY=0.57, RCX=0.44, BBox=(420,731,12,6)
# Unclassified Cand 77: Len=23.6, Angle=31.0, Straight=0.06, RCY=0.60, RCX=0.48, BBox=(460,766,11,7)
# Unclassified Cand 78: Len=23.7, Angle=0.0, Straight=0.07, RCY=0.98, RCX=0.26, BBox=(245,1259,15,2)
# Unclassified Cand 79: Len=23.8, Angle=36.9, Straight=0.05, RCY=0.58, RCX=0.46, BBox=(435,739,11,9)
# Unclassified Cand 80: Len=24.0, Angle=0.0, Straight=0.00, RCY=0.18, RCX=0.65, BBox=(621,223,1,25)
# Unclassified Cand 81: Len=24.3, Angle=41.2, Straight=0.25, RCY=0.58, RCX=0.45, BBox=(428,741,9,8)
# Unclassified Cand 82: Len=24.7, Angle=82.9, Straight=0.07, RCY=0.60, RCX=0.78, BBox=(747,767,3,14)
# Unclassified Cand 83: Len=25.6, Angle=40.6, Straight=0.05, RCY=0.72, RCX=0.72, BBox=(683,920,11,9)
# Unclassified Cand 84: Len=25.6, Angle=135.0, Straight=0.06, RCY=0.96, RCX=0.48, BBox=(458,1229,10,10)
# Unclassified Cand 85: Len=25.7, Angle=99.5, Straight=0.12, RCY=0.86, RCX=0.15, BBox=(139,1088,4,14)
# Unclassified Cand 86: Len=25.8, Angle=84.8, Straight=0.06, RCY=0.57, RCX=0.77, BBox=(742,729,2,15)
# Unclassified Cand 87: Len=25.9, Angle=39.8, Straight=0.35, RCY=0.49, RCX=0.50, BBox=(476,625,11,7)
# Unclassified Cand 88: Len=26.3, Angle=20.0, Straight=0.26, RCY=0.41, RCX=0.68, BBox=(643,526,12,6)
# Unclassified Cand 89: Len=26.5, Angle=0.0, Straight=0.44, RCY=0.48, RCX=0.35, BBox=(337,609,10,5)
# Unclassified Cand 90: Len=29.2, Angle=35.5, Straight=0.07, RCY=0.62, RCX=0.36, BBox=(334,788,15,11)
# Unclassified Cand 91: Len=30.7, Angle=174.3, Straight=0.06, RCY=0.28, RCX=0.47, BBox=(444,355,22,3)
# Unclassified Cand 92: Len=31.2, Angle=50.2, Straight=0.09, RCY=0.49, RCX=0.49, BBox=(463,619,13,14)
# Unclassified Cand 93: Len=31.5, Angle=127.9, Straight=0.04, RCY=0.85, RCX=0.25, BBox=(235,1082,11,14)
# Unclassified Cand 94: Len=31.5, Angle=85.9, Straight=0.11, RCY=0.51, RCX=0.50, BBox=(481,642,3,16)
# Unclassified Cand 95: Len=32.5, Angle=12.5, Straight=0.09, RCY=0.51, RCX=0.46, BBox=(433,656,17,5)
# Unclassified Cand 96: Len=33.3, Angle=127.6, Straight=0.08, RCY=0.82, RCX=0.29, BBox=(269,1041,11,14)
# Unclassified Cand 97: Len=33.7, Angle=96.3, Straight=0.05, RCY=0.79, RCX=0.77, BBox=(741,1005,3,20)
# Unclassified Cand 98: Len=34.6, Angle=129.3, Straight=0.13, RCY=0.68, RCX=0.18, BBox=(163,859,12,14)
# Unclassified Cand 99: Len=35.5, Angle=78.7, Straight=0.08, RCY=0.61, RCX=0.54, BBox=(517,770,4,19)
# Unclassified Cand 100: Len=36.4, Angle=72.6, Straight=0.18, RCY=0.67, RCX=0.63, BBox=(603,852,7,17)
# Unclassified Cand 101: Len=36.9, Angle=90.0, Straight=0.20, RCY=0.51, RCX=0.00, BBox=(0,640,4,16)
# Unclassified Cand 102: Len=37.1, Angle=74.7, Straight=0.05, RCY=0.69, RCX=0.54, BBox=(514,875,6,19)
# Unclassified Cand 103: Len=37.6, Angle=72.6, Straight=0.09, RCY=0.65, RCX=0.52, BBox=(500,827,7,18)
# Unclassified Cand 104: Len=37.8, Angle=18.4, Straight=0.12, RCY=0.57, RCX=0.33, BBox=(309,734,18,8)
# Unclassified Cand 105: Len=38.6, Angle=39.3, Straight=0.15, RCY=0.60, RCX=0.74, BBox=(698,753,16,11)
# Unclassified Cand 106: Len=38.8, Angle=93.6, Straight=0.04, RCY=0.31, RCX=0.75, BBox=(717,385,2,23)
# Unclassified Cand 107: Len=38.9, Angle=139.8, Straight=0.14, RCY=0.08, RCX=0.62, BBox=(593,94,15,13)
# Unclassified Cand 108: Len=41.7, Angle=96.0, Straight=0.05, RCY=0.15, RCX=0.65, BBox=(623,184,3,22)
# Unclassified Cand 109: Len=42.5, Angle=8.1, Straight=0.39, RCY=0.42, RCX=0.71, BBox=(675,535,17,8)
# Unclassified Cand 110: Len=42.9, Angle=3.8, Straight=0.13, RCY=0.28, RCX=0.36, BBox=(337,362,21,4)
# Unclassified Cand 111: Len=44.5, Angle=0.0, Straight=0.04, RCY=0.38, RCX=0.49, BBox=(460,489,25,2)
# Unclassified Cand 112: Len=44.8, Angle=141.3, Straight=0.05, RCY=0.91, RCX=0.50, BBox=(472,1161,22,18)
# Unclassified Cand 113: Len=45.0, Angle=48.8, Straight=0.05, RCY=0.68, RCX=0.61, BBox=(576,863,16,18)
# Unclassified Cand 114: Len=45.1, Angle=156.4, Straight=0.23, RCY=0.47, RCX=0.36, BBox=(326,599,20,9)
# Unclassified Cand 115: Len=46.0, Angle=11.9, Straight=0.13, RCY=0.28, RCX=0.37, BBox=(354,355,22,6)
# Unclassified Cand 116: Len=46.1, Angle=100.9, Straight=0.08, RCY=0.77, RCX=0.78, BBox=(744,973,6,27)
# Unclassified Cand 117: Len=48.1, Angle=165.3, Straight=0.09, RCY=0.27, RCX=0.47, BBox=(436,337,25,6)
# Unclassified Cand 118: Len=49.1, Angle=48.8, Straight=0.18, RCY=0.47, RCX=0.48, BBox=(446,590,17,18)
# Unclassified Cand 119: Len=52.4, Angle=15.3, Straight=0.09, RCY=0.95, RCX=0.40, BBox=(373,1206,25,8)
# Unclassified Cand 120: Len=52.8, Angle=91.7, Straight=0.02, RCY=0.74, RCX=0.78, BBox=(750,929,2,43)
# Unclassified Cand 121: Len=53.3, Angle=71.6, Straight=0.20, RCY=0.95, RCX=0.98, BBox=(939,1208,9,25)
# Unclassified Cand 122: Len=54.0, Angle=165.4, Straight=0.08, RCY=0.52, RCX=0.17, BBox=(146,657,27,7)
# Unclassified Cand 123: Len=56.9, Angle=49.9, Straight=0.04, RCY=0.73, RCX=0.42, BBox=(398,919,21,24)
# Unclassified Cand 124: Len=58.1, Angle=23.2, Straight=0.22, RCY=0.57, RCX=0.42, BBox=(391,715,23,14)
# Unclassified Cand 125: Len=59.4, Angle=62.4, Straight=0.06, RCY=0.61, RCX=0.44, BBox=(417,772,14,26)
# Unclassified Cand 126: Len=60.3, Angle=8.1, Straight=0.06, RCY=0.27, RCX=0.51, BBox=(471,347,32,6)
# Unclassified Cand 127: Len=63.2, Angle=169.7, Straight=0.28, RCY=0.59, RCX=0.60, BBox=(555,747,25,8)
# Unclassified Cand 128: Len=63.9, Angle=126.9, Straight=0.05, RCY=0.88, RCX=0.33, BBox=(311,1115,19,26)
# Unclassified Cand 129: Len=67.6, Angle=14.9, Straight=0.05, RCY=0.42, RCX=0.46, BBox=(429,539,32,9)
# Unclassified Cand 130: Len=67.8, Angle=18.4, Straight=0.47, RCY=0.23, RCX=0.66, BBox=(620,282,23,15)
# Unclassified Cand 131: Len=68.7, Angle=143.8, Straight=0.05, RCY=0.61, RCX=0.22, BBox=(195,767,28,20)
# Unclassified Cand 132: Len=71.8, Angle=88.3, Straight=0.02, RCY=0.47, RCX=0.75, BBox=(720,572,2,53)
# Unclassified Cand 133: Len=73.3, Angle=14.0, Straight=0.53, RCY=0.49, RCX=0.34, BBox=(322,618,18,13)
# Unclassified Cand 134: Len=79.0, Angle=76.0, Straight=0.19, RCY=0.89, RCX=0.14, BBox=(134,1118,10,32)
# Unclassified Cand 135: Len=79.4, Angle=7.8, Straight=0.38, RCY=0.15, RCX=0.49, BBox=(460,191,24,13)
# Unclassified Cand 136: Len=87.8, Angle=19.7, Straight=0.45, RCY=0.43, RCX=0.70, BBox=(657,540,31,15)
# Unclassified Cand 137: Len=88.4, Angle=159.3, Straight=0.06, RCY=0.42, RCX=0.37, BBox=(337,527,40,17)
# Unclassified Cand 138: Len=90.8, Angle=88.6, Straight=0.02, RCY=0.63, RCX=0.78, BBox=(750,782,2,50)
# Unclassified Cand 139: Len=92.6, Angle=9.5, Straight=0.09, RCY=0.26, RCX=0.50, BBox=(457,326,47,7)
# Unclassified Cand 140: Len=96.6, Angle=99.5, Straight=0.06, RCY=0.83, RCX=0.76, BBox=(729,1040,9,48)
# Unclassified Cand 141: Len=97.6, Angle=1.2, Straight=0.05, RCY=0.53, RCX=0.17, BBox=(137,676,48,4)
# Unclassified Cand 142: Len=104.5, Angle=148.4, Straight=0.11, RCY=0.93, RCX=0.47, BBox=(427,1182,43,27)
# Unclassified Cand 143: Len=111.1, Angle=46.3, Straight=0.48, RCY=0.40, RCX=0.71, BBox=(662,508,29,25)
# Unclassified Cand 144: Len=112.8, Angle=1.8, Straight=0.15, RCY=0.41, RCX=0.48, BBox=(449,516,45,8)
# Unclassified Cand 145: Len=121.0, Angle=30.7, Straight=0.10, RCY=0.55, RCX=0.40, BBox=(362,686,49,29)
# Unclassified Cand 146: Len=125.1, Angle=63.4, Straight=0.17, RCY=0.10, RCX=0.64, BBox=(603,110,25,50)
# Unclassified Cand 147: Len=129.2, Angle=1.3, Straight=0.16, RCY=0.29, RCX=0.50, BBox=(438,361,53,10)
# Unclassified Cand 148: Len=129.8, Angle=78.0, Straight=0.06, RCY=0.47, RCX=0.45, BBox=(422,565,14,62)
# Unclassified Cand 149: Len=171.3, Angle=88.4, Straight=0.03, RCY=0.36, RCX=0.75, BBox=(716,426,6,114)
# Unclassified Cand 150: Len=190.1, Angle=104.6, Straight=0.07, RCY=0.82, RCX=0.47, BBox=(443,1005,24,90)
# Unclassified Cand 151: Len=216.4, Angle=54.3, Straight=0.52, RCY=0.91, RCX=0.94, BBox=(889,1158,43,61)
# Unclassified Cand 152: Len=231.1, Angle=42.9, Straight=0.03, RCY=0.65, RCX=0.57, BBox=(489,781,83,79)
# Unclassified Cand 153: Len=241.8, Angle=66.0, Straight=0.09, RCY=0.63, RCX=0.43, BBox=(386,761,40,85)
# Unclassified Cand 154: Len=369.7, Angle=39.8, Straight=0.14, RCY=0.57, RCX=0.54, BBox=(434,643,126,107)
# Unclassified Cand 155: Len=488.6, Angle=180.0, Straight=0.28, RCY=0.98, RCX=0.97, BBox=(821,1237,139,39)
